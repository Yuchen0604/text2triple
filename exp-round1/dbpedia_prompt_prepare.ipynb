# %%
import utils 
import os

# %%
# base directory path
base_dir = r"c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1"
data_dir = os.path.join(base_dir, "data")
dbpedia_dir = os.path.join(data_dir, "dbpedia_webnlg")
dbpedia_new_dir = os.path.join(data_dir, "dbpedia_new")

ontology_file_path = os.path.join(dbpedia_dir, "ontologies", "19_film_ontology.json")
test_file_path = os.path.join(dbpedia_dir, "test/ont_19_film_test.jsonl")
similarity_file_path = os.path.join(dbpedia_dir, "baselines", "test_train_sent_similarity/19_film_test_train_similarity.json")
train_file_path = os.path.join(dbpedia_dir, "train/ont_19_film_train.jsonl")
ground_truth_file_path = os.path.join(dbpedia_dir, "ground_truth/ont_19_film_ground_truth.jsonl")

# %%
ontology = utils.load_json(ontology_file_path)
tests = utils.load_jsonl(test_file_path)
test_train_similarity = utils.load_json(similarity_file_path)
train = utils.load_jsonl(train_file_path)
ground_truth = utils.load_jsonl(ground_truth_file_path)
print(f"ontology: {ontology}")
print(f"tests: {len(tests)}")
print(f"test_train_similarity: {len(test_train_similarity.keys())}")
print(f"train: {len(train)}")
print(f"ground_truth: {len(ground_truth)}")
# Out:
# ontology: {'title': 'Film Ontology', 'id': 'ont_19_film', 'concepts': [{'qid': 'Film', 'label': 'Film'}, {'qid': 'Channel', 'label': 'Channel'}, {'qid': 'Organisation', 'label': 'Organisation'}, {'qid': 'Company', 'label': 'Company'}, {'qid': 'Artist', 'label': 'Artist'}, {'qid': 'Type', 'label': 'Type'}, {'qid': 'Place', 'label': 'Place'}, {'qid': 'City', 'label': 'City'}, {'qid': 'Industry', 'label': 'Industry'}, {'qid': 'Occupation', 'label': 'Occupation'}, {'qid': 'Person', 'label': 'Person'}, {'qid': 'Country', 'label': 'Country'}, {'qid': 'Background', 'label': 'Background'}, {'qid': 'Service', 'label': 'Service'}, {'qid': 'Cinematography', 'label': 'Cinematography'}, {'qid': 'Language', 'label': 'Language'}, {'qid': 'Station', 'label': 'Station'}, {'qid': 'Club', 'label': 'Club'}], 'relations': [{'pid': 'timeshiftChannel', 'label': 'timeshiftChannel', 'domain': 'Film', 'range': 'Channel'}, {'pid': 'director', 'label': 'director', 'domain': 'Film', 'range': 'Person'}, {'pid': 'imdbId', 'label': 'imdbId', 'domain': 'Film', 'range': 'string'}, {'pid': 'distributor', 'label': 'distributor', 'domain': 'Film', 'range': 'Company'}, {'pid': 'musicComposer', 'label': 'musicComposer', 'domain': 'Film', 'range': 'Artist'}, {'pid': 'type', 'label': 'type', 'domain': 'Film', 'range': 'Type'}, {'pid': 'deathDate', 'label': 'deathDate', 'domain': 'Artist', 'range': 'Date'}, {'pid': 'club', 'label': 'club', 'domain': 'Film', 'range': 'Club'}, {'pid': 'editing', 'label': 'editing', 'domain': 'Film', 'range': 'Artist'}, {'pid': 'releaseDate', 'label': 'releaseDate', 'domain': 'Film', 'range': 'Date'}, {'pid': 'child', 'label': 'child', 'domain': 'Artist', 'range': 'Person'}, {'pid': 'producer', 'label': 'producer', 'domain': 'Film', 'range': 'Person'}, {'pid': 'birthPlace', 'label': 'birthPlace', 'domain': 'Artist', 'range': 'Place'}, {'pid': 'headquarter', 'label': 'headquarter', 'domain': 'Company', 'range': 'City'}, {'pid': 'deathPlace', 'label': 'deathPlace', 'domain': 'Artist', 'range': 'Place'}, {'pid': 'location', 'label': 'location', 'domain': 'Company', 'range': 'Place'}, {'pid': 'budget', 'label': 'budget', 'domain': 'Film', 'range': 'number'}, {'pid': 'runtime', 'label': 'runtime', 'domain': 'Film', 'range': 'number'}, {'pid': 'owner', 'label': 'owner', 'domain': 'Company', 'range': 'Person'}, {'pid': 'starring', 'label': 'starring', 'domain': 'Film', 'range': 'Artist'}, {'pid': 'iso6392Code', 'label': 'iso6392Code', 'domain': 'City', 'range': 'string'}, {'pid': 'writer', 'label': 'writer', 'domain': 'WrittenWork', 'range': 'Person'}, {'pid': 'industry', 'label': 'industry', 'domain': 'Company', 'range': 'Industry'}, {'pid': 'activeYearsStartYear', 'label': 'activeYearsStartYear', 'domain': 'Artist', 'range': 'Year'}, {'pid': 'occupation', 'label': 'occupation', 'domain': 'Artist', 'range': 'Occupation'}, {'pid': 'sisterStation', 'label': 'sisterStation', 'domain': 'Film', 'range': 'Station'}, {'pid': 'spouse', 'label': 'spouse', 'domain': 'Artist', 'range': 'Person'}, {'pid': 'spokenIn', 'label': 'spokenIn', 'domain': 'Language', 'range': 'Country'}, {'pid': 'gross', 'label': 'gross', 'domain': 'Film', 'range': 'number'}, {'pid': 'formerName', 'label': 'formerName', 'domain': 'Artist', 'range': 'string'}, {'pid': 'birthYear', 'label': 'birthYear', 'domain': 'Artist', 'range': 'Year'}, {'pid': 'birthName', 'label': 'birthName', 'domain': 'Artist', 'range': 'string'}, {'pid': 'editor', 'label': 'editor', 'domain': 'Film', 'range': 'Person'}, {'pid': 'language', 'label': 'language', 'domain': 'Film', 'range': 'Language'}, {'pid': 'background', 'label': 'background', 'domain': 'Film', 'range': 'Background'}, {'pid': 'service', 'label': 'service', 'domain': 'Company', 'range': 'Service'}, {'pid': 'cinematography', 'label': 'cinematography', 'domain': 'Film', 'range': 'Cinematography'}, {'pid': 'deathYear', 'label': 'deathYear', 'domain': 'Artist', 'range': 'Year'}, {'pid': 'birthDate', 'label': 'birthDate', 'domain': 'Artist', 'ra ...
# tests: 127
# test_train_similarity: 127
# train: 137
# ground_truth: 127

# %%
def get_one_example_prompt(train_sent):
    example_prompt = "\n\nExample Sentence: " + train_sent['sent']
    
    # Extracting the first triple from the list of triples
    triples = train_sent['triples']

    triples_string = ""
    for triple in triples:
        # Constructing the string representation of each triple
        triples_string += triple['rel'] + "(" + triple['sub'] + "," + triple['obj'] + ")" + ", "
    
    # Constructing the example output based on the new format
    example_prompt += "\nExample Output: " + triples_string 
    
    return example_prompt

# %%
# get domain and range of a relation    
def get_domain_range(relation: str, ontology: dict):
    """
    Returns the domain and range of a given relation label from the ontology data.
    
    :param relation: The label of the relation (string)
    :param data: The ontology data (dictionary loaded from JSON)
    :return: A tuple (domain, range) or (None, None) if relation not found
    """
    # Create a mapping of qid to label for concepts
    concept_map = {concept["qid"]: concept["label"] for concept in ontology.get("concepts", [])}
    
    for rel in ontology.get("relations", []):
        if rel.get("label") == relation:
            domain_id = rel.get("domain")
            range_id = rel.get("range")
            return concept_map.get(domain_id, None), concept_map.get(range_id, None)
    
    return None, None  # Return None if relation is not found

# get n ground truth ontology relations
def get_n_ontology_relations(gt_list: list, id, ontology: dict):
    gt_relations = []
    gt_id = id
    ontology = ontology
    for item in gt_list:
        if item['id'] == gt_id:
            triples = item['triples']
            break
    if triples == None:
        return "No triples found for the given id"        

    for triple in triples:
        gt_relations.append(triple['rel'])

    # remove duplicates
    gt_relations = list(set(gt_relations))
    return gt_relations
    
# get ontology prompt
def get_ontology_prompt(gt_rels: list, ontology: dict):

    onto_relations = ""
    for rel in gt_rels:
        domain, range = get_domain_range(rel, ontology)
        rel_string = rel.replace(" ", "_")
        if domain == None:
            domain = ""
        if range == None:
            range = ""
        onto_relations += f"{rel_string}({domain}, {range}), "
    return onto_relations


def get_three_example_prompt(simil_sent_id: list, train: list):
    three_example_prompt = ""
    for id in simil_sent_id:
        train_sent = get_train_sentence(id, train)
        one_example_prompt = get_one_example_prompt(train_sent)
        three_example_prompt += one_example_prompt + "\n"
    return three_example_prompt
        

# get test prompt
def get_test_prompt(test_sentence):
    test_prompt = "\n\nTest Sentence: " + test_sentence
    test_prompt += "\nTest Output: "
    return test_prompt


def get_similar_sentences(test_sentence_id, test_similar):
    for sim in test_similar:
        if sim == test_sentence_id:
            return test_similar[sim]


def get_train_sentence(simil_sent_id, train_sentences):
    for sent in train_sentences:
        if sent['id'] == simil_sent_id:
            return sent

# %%
# prepare prompt    
def prepare_prompt_zero_shot(test_sentence: str, gt_relations:list, ontology:dict) -> str:


    prompt_fixed = '''Extract relational triplets from the sentence based on the provided ontology relations.
Use only the listed relations and ensure subjects and objects align with their specified restrictions.
Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n
'''

    prompt = prompt_fixed
    prompt += 'CONTEXT:\n\n'
    prompt += '\nOntology Relations: '
    prompt += get_ontology_prompt(gt_relations, ontology)
    prompt += get_test_prompt(test_sentence)

    return prompt


def prepare_prompt_one_shot(test_sentence: str, gt_relations:list, ontology:dict, train_sent:dict) -> str:


    prompt_fixed = '''Extract relational triplets from the sentence based on the provided ontology relations and examples.
Use only the listed relations and ensure subjects and objects align with their specified restrictions.
Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n
'''

    prompt = prompt_fixed
    prompt += 'CONTEXT:\n\n'
    prompt += '\nOntology Relations: '
    prompt += get_ontology_prompt(gt_relations, ontology)
    prompt += get_one_example_prompt(train_sent)
    prompt += get_test_prompt(test_sentence)

    return prompt


def prepare_prompt_three_shot(test_sentence: str, gt_relations:list, ontology:dict, simil_sent_id: list, train: list) -> str:


    prompt_fixed = '''Extract relational triplets from the sentence based on the provided ontology relations and examples.
Use only the listed relations and ensure subjects and objects align with their specified restrictions.
Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n
'''

    prompt = prompt_fixed
    prompt += 'CONTEXT:\n\n'
    prompt += '\nOntology Relations: '
    prompt += get_ontology_prompt(gt_relations, ontology)
    prompt += get_three_example_prompt(simil_sent_id, train)
    prompt += get_test_prompt(test_sentence)

    return prompt

# %% [markdown]
# # generate n ground truth relation, prompts and save to the output file

# %%
output_folder_path = os.path.join(dbpedia_new_dir, "n_rels_0_distractors")
os.makedirs(output_folder_path, exist_ok=True)  # Will not throw an error if the folder exists

# %%
for item in tests:
    id = item["id"]
    item["gt_relations"] = get_n_ontology_relations(ground_truth, id, ontology)
    print(item["gt_relations"])
# Out:
# ['starring', 'writer', 'musicComposer']
# ['director', 'writer', 'runtime', 'starring', 'budget']
# ['starring']
# ['director']
# ['type', 'distributor']
# ['starring', 'gross']
# ['starring', 'writer', 'runtime']
# ['starring', 'cinematography']
# ['director', 'starring', 'runtime']
# ['birthYear', 'writer', 'starring']
# ['starring', 'runtime', 'gross', 'cinematography']
# ['writer']
# ['starring', 'activeYearsStartYear']
# ['starring', 'editing', 'language']
# ['starring']
# ['starring', 'birthPlace']
# ['starring', 'editing', 'musicComposer', 'runtime']
# ['starring', 'musicComposer', 'director', 'runtime']
# ['director', 'runtime', 'gross', 'cinematography']
# ['director', 'runtime', 'distributor', 'starring', 'gross']
# ['starring', 'gross', 'distributor']
# ['starring', 'runtime']
# ['starring', 'birthDate', 'birthPlace']
# ['starring', 'writer']
# ['starring', 'writer', 'budget', 'director']
# ['starring', 'runtime', 'gross', 'cinematography']
# ['director', 'runtime', 'starring', 'gross', 'cinematography', 'musicComposer']
# ['cinematography']
# ['starring', 'distributor', 'runtime']
# ['starring', 'gross', 'director', 'runtime']
# ['director', 'editing', 'activeYearsStartYear', 'runtime']
# ['spouse']
# ['director', 'writer', 'runtime', 'starring', 'gross', 'cinematography', 'musicComposer']
# ['distributor']
# ['director', 'writer', 'musicComposer', 'runtime']
# ['language', 'distributor', 'runtime', 'starring', 'editing']
# ['starring', 'birthPlace']
# ['director', 'editing', 'musicComposer', 'deathYear']
# ['writer', 'runtime', 'starring', 'editing', 'musicComposer']
# ['birthYear']
# ['activeYearsStartYear']
# ['director', 'starring']
# ['keyPerson']
# ['gross', 'budget', 'runtime']
# ['language', 'writer', 'distributor', 'runtime', 'editing', 'budget']
# ['starring', 'editing', 'language']
# ['starring', 'gross', 'cinematography']
# ['writer']
# ['deathPlace']
# ['starring', 'distributor', 'runtime']
# ['starring']
# ['starring', 'distributor', 'foundingYear']
# ['birthDate']
# ['starring', 'distributor']
# ['director', 'runtime', 'starring', 'gross', 'cinematography']
# ['starring', 'writer', 'gross', 'runtime']
# ['starring', 'writer', 'deathYear', 'director']
# ['type', 'language', 'distributor', 'iso6391Code']
# ['language', 'distributor', 'runtime', 'starring', 'editing']
# ['birthYear', 'writer', 'starring']
# ['director', 'musicComposer', 'runtime']
# ['starring', 'director']
# ['starring']
# ['musicComposer', 'birthDate']
# ['starring', 'writer', 'director']
# ['starring', 'budget', 'distributor']
# ['starring', 'gross', 'runtime']
# ['starring', 'writer', 'gross', 'director']
# ['starring', 'language']
# ['starring', 'editing', 'language', 'runtime']
# ['director', 'gross', 'musicComposer', 'runtime']
# ['language', 'spokenIn', 'activeYearsStartYear', 'starring']
# ['runtime', 'starring', 'gross', 'cinematography', 'musicComposer']
# ['starring', 'writer', 'editing']
# ['director', 'runtime', 'distributor']
# ['director', 'runtime', 'starring', 'gross', 'cinematography', 'musicComposer']
# ['director', 'occupation']
# ['runtime']
# ['spouse']
# ['starring', 'distributor']
# ['service']
# ['starring', 'editing']
# ['location']
# ['starring', 'language', 'runtime']
# ['gross']
# ['language']
# ['musicComposer']
# ['industry']
# ['child']
# ['service']
# ['distributor', 'service']
# ['starring', 'birthYear']
# ['keyPerson']
# ['deathPlace']
# ['director', 'birthPlace']
# ['starring', 'keyPerson', 'director', 'distributor']
# ['director', 'writer', 'runtime', 'editing', 'gross', 'budget']
# ['musicComposer', 'birthPlace']
# ['starring']
# ['starring', 'writer']
# ['director', 'runtime', 'starring', 'gross', 'cinematography']
# ['activeYearsStartYear']
# ['spouse']
# ['birthPlace']
# ['starring', 'spouse']
# ['director', 'runtime', 'starring', 'cinematography', 'musicComposer']
# ['editing', 'musicComposer', 'cinematography']
# ['language', 'editing', 'distributor', 'runtime']
# ['occupation']
# ['birthPlace']
# ['starring']
# ['starring', 'musicComposer']
# ['director']
# ['starring', 'occupation']
# ['starring', 'deathPlace']
# ['starring', 'birthYear']
# ['starring', 'birthName', 'deathPlace']
# ['occupation']
# ['director', 'runtime']
# ['child']
# ['iso6392Code']
# ['language', 'writer', 'runtime', 'starring', 'editing', 'budget']
# ['starring', 'editing', 'musicComposer']
# ['director', 'writer', 'runtime', 'starring', 'musicComposer']
# ['starring', 'editing', 'language', 'distributor']
# ['starring']
# ['distributor', 'foundedBy']

# %%
new_test_file_path = os.path.join(output_folder_path, "ont_19_film_test.jsonl")
utils.save_jsonl(tests, new_test_file_path)
# Out:
# Saved JSONL data to c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\data\dbpedia_new\n_rels_0_distractors\ont_19_film_test.jsonl

# %%
zero_shot_prompts = []
for item in tests:
    prompt_item = {}
    prompt_item["id"] = item["id"]
    prompt_item["prompt"]= prepare_prompt_zero_shot(item["sent"], item["gt_relations"], ontology)
    print(prompt_item["id"])
    print(prompt_item["prompt"])
    print("-------------------")
    zero_shot_prompts.append(prompt_item)
# Out:
# ont_19_film_test_1
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), musicComposer(Film, Artist),
#
# Test Sentence: It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_2
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), budget(Film, ),
#
# Test Sentence: Super Capers is a 98 minute film with a $2000000.0 budget. It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_3
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Test Sentence: Cecil Parker had a main role in It's Great to Be Young.
# Test Output:
# -------------------
# ont_19_film_test_4
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person),
#
# Test Sentence: The movie "Super Capers" was directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_5
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: type(Film, Type), distributor(Film, Company),
#
# Test Sentence: Super Capers was distributed by the public company Lionsgate. It was also distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_6
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ),
#
# Test Sentence: John Mills had a main role in the movie It's Great to Be Young which has taken 282,838 pounds at the box office.
# Test Output:
# -------------------
# ont_19_film_test_7
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), runtime(Film, ),
#
# Test Sentence: Super Capers, a film written by Ray Griggs, is 98 minutes long. Danielle Harris was one of the stars of the movie.
# Test Output:
# -------------------
# ont_19_film_test_8
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), cinematography(Film, Cinematography),
#
# Test Sentence: John Mills starred in the 1956 film It’s Great to Be Young which featured cinematography by Gilbert Taylor.
# Test Output:
# -------------------
# ont_19_film_test_9
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), starring(Film, Artist), runtime(Film, ),
#
# Test Sentence: The 1956 movie It's Great to Be Young was directed by Cyril Frankel, starred Cecil Parker, and has a running time of 94 minutes.
# Test Output:
# -------------------
# ont_19_film_test_10
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthYear(Artist, ), writer(, Person), starring(Film, Artist),
#
# Test Sentence: Director Ray Griggs, born in 1974, is the writer of the film Super Capers, starring Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_11
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Test Sentence: John Mills and Cecil Parker starred in the 1956 movie It's Great to Be Young which runs 94 minutes and had Gilbert Taylor as the cinematographer. The movie costed £282,838.
# Test Output:
# -------------------
# ont_19_film_test_12
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: writer(, Person),
#
# Test Sentence: Writer of the 1956 film It's Great to Be Young is Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_13
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), activeYearsStartYear(Artist, ),
#
# Test Sentence: Tom Sizemore, who began acting in 1989, and Adam West have both starred in Super Capers.
# Test Output:
# -------------------
# ont_19_film_test_14
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language),
#
# Test Sentence: The English-language film Super Capers was edited by Stacy Katzman and played by Michael Rooker.
# Test Output:
# -------------------
# ont_19_film_test_15
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Test Sentence: Tom Sizemore stars in Super Capers which starred Michael Rooker.
# Test Output:
# -------------------
# ont_19_film_test_16
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthPlace(Artist, Place),
#
# Test Sentence: Super Capers starred Michael Rooker, who was born in Jasper, Alabama.
# Test Output:
# -------------------
# ont_19_film_test_17
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist), runtime(Film, ),
#
# Test Sentence: It's great to be young is a movie from 1956 that runs for 94 minutes. It stars Cecil Parker and it’s edited by Max Benedict. Louis Levy composed the music.
# Test Output:
# -------------------
# ont_19_film_test_18
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), musicComposer(Film, Artist), director(Film, Person), runtime(Film, ),
#
# Test Sentence: John Mills played the lead role and Cecil Parker had a main role in the movie It's Great to Be Young. The movie was released in 1956 and had a duration of 94 minutes. Cyril Frankel is the director and Louis Levy is the music composer of the movie.
# Test Output:
# -------------------
# ont_19_film_test_19
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Test Sentence: Gilbert Taylor was the cinematographer while Cyril Frankel was the director of the movie It's Great to Be Young. It came out in 1956 and lasted 94 minutes and accumulated 282,838 pounds.
# Test Output:
# -------------------
# ont_19_film_test_20
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), distributor(Film, Company), starring(Film, Artist), gross(Film, ),
#
# Test Sentence: “Super Capers” is a 98-minute-long movie starring Tom Lister Jr. Distributed by Lionsgate, the film grossed $30,955. Ray Griggs was the director of the film.
# Test Output:
# -------------------
# ont_19_film_test_21
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), distributor(Film, Company),
#
# Test Sentence: The film Super Capers, distributed by Lionsgate and starring Justin Whalin, grossed $30,955.
# Test Output:
# -------------------
# ont_19_film_test_22
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ),
#
# Test Sentence: Super Capers, a film that had a running time of 98 minutes, stars Justin Whalin.
# Test Output:
# -------------------
# ont_19_film_test_23
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthDate(Artist, ), birthPlace(Artist, Place),
#
# Test Sentence: Super Capers stars the actors Justin Whalin and Michael Rooker. Whalin was born in San Francisco and while the birth location of Rooker is unknown, he was born on April 6th, 1955.
# Test Output:
# -------------------
# ont_19_film_test_24
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person),
#
# Test Sentence: Ted Willis wrote “It’s great to be young” a 1956 film starring Cecil Parker.
# Test Output:
# -------------------
# ont_19_film_test_25
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), budget(Film, ), director(Film, Person),
#
# Test Sentence: Super Capers, whose budget was 2000000, was lead by Adam West, and both written and directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_26
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Test Sentence: It's Great to Be Young is a 1956 film in which John Mills played a lead role. The film featured Gilbert Taylor as a cinematographer, and it received £282,838. The duration of the film is around 94 minutes.
# Test Output:
# -------------------
# ont_19_film_test_27
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Test Sentence: The popular 1956 film, It's Great to Be Young, starred English actors John Mills and Cecil Parker, and was directed by Cyril Frankel. Cinematography was by Gilbert Taylor, with composition for the musical comedy by Louis Levy. The film's running time is 94 minutes, and, according to the Historical Journal of Film, Radio and Television, was produced for 282,838 pounds.
# Test Output:
# -------------------
# ont_19_film_test_28
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: cinematography(Film, Cinematography),
#
# Test Sentence: It's Great to Be Young had Gilbert Taylor as cinematographer.
# Test Output:
# -------------------
# ont_19_film_test_29
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), distributor(Film, Company), runtime(Film, ),
#
# Test Sentence: Tom Sizemore starred in the 98.0 minutes long movie Super Capers which was distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_30
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), director(Film, Person), runtime(Film, ),
#
# Test Sentence: It's Great to Be Young, a 1956 film directed by Cyril Frankel, received £282,838. John Mills plays the lead in this 94-minute long movie.
# Test Output:
# -------------------
# ont_19_film_test_31
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), editing(Film, Artist), activeYearsStartYear(Artist, ), runtime(Film, ),
#
# Test Sentence: It's Great to Be Young (1956, 94 minutes) is a film edited by Max Benedict, who has been active in the film industry since 1947. The director of the movie is Cyril Frankel.
# Test Output:
# -------------------
# ont_19_film_test_32
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: spouse(Artist, Person),
#
# Test Sentence: Tom Sizemore was married to Maeve Quinlan.
# Test Output:
# -------------------
# ont_19_film_test_33
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Test Sentence: It’s Great to Be Young is a 1956 film that lasts 94 minutes. It was directed by Cyril Frankel and its writer was Ted Willis. John Mills played in the film, and it collected 282,838 at the box office. The film music was written by Louis Levy, and Gilbert Taylor served as a cinematographer.
# Test Output:
# -------------------
# ont_19_film_test_34
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: distributor(Film, Company),
#
# Test Sentence: Distributor of the movie Super Capers is Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_35
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), musicComposer(Film, Artist), runtime(Film, ),
#
# Test Sentence: The 1956 film 'It's great to be young', directed by Cyril Frankel, is 94 minutes long. The music was composed by Louis Levy, while the writer is Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_36
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), distributor(Film, Company), runtime(Film, ), starring(Film, Artist), editing(Film, Artist),
#
# Test Sentence: Super Capers is a 98.0 minute long English-language film starring Michael Rooker and Tom Sizemore. The film was edited by Stacy Katzman and distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_37
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthPlace(Artist, Place),
#
# Test Sentence: It's Great to Be Young (1956) stars John Mills, who was born in North Elmham.
# Test Output:
# -------------------
# ont_19_film_test_38
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), editing(Film, Artist), musicComposer(Film, Artist), deathYear(Artist, ),
#
# Test Sentence: The 1956 movie , It's Great to be Young, was edited by Max Benedict who later died in 1986. The director was Cyril Frankel and the music composer was Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_39
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: writer(, Person), runtime(Film, ), starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist),
#
# Test Sentence: It's Great to Be Young is a 1956 film that stars Cecil Parker and John Mills. The length of the movie is 94 minutes and written by Ted Willis. It’s edited by Max Benedict and the score is composed by Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_40
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthYear(Artist, ),
#
# Test Sentence: Michael Rooker was born in the year 1955.
# Test Output:
# -------------------
# ont_19_film_test_41
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: activeYearsStartYear(Artist, ),
#
# Test Sentence: Tom Sizemore began his career in 1989.
# Test Output:
# -------------------
# ont_19_film_test_42
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), starring(Film, Artist),
#
# Test Sentence: Cecil Parker starred in the 1956 movie It's Great to Be Young, directed by Cyril Frankel.
# Test Output:
# -------------------
# ont_19_film_test_43
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: keyPerson(Organisation, Person),
#
# Test Sentence: Michael R Burns plays an important role for the company Lionsgate.
# Test Output:
# -------------------
# ont_19_film_test_44
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: gross(Film, ), budget(Film, ), runtime(Film, ),
#
# Test Sentence: The film Super Capers is 98 minutes long. The budget was 2,000,000 but the gross income was only $30,955.
# Test Output:
# -------------------
# ont_19_film_test_45
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), writer(, Person), distributor(Film, Company), runtime(Film, ), editing(Film, Artist), budget(Film, ),
#
# Test Sentence: Super Capers is a 98 minute English movie that was distributed by Roadside Attractions and Lionsgate. It was directed by Ray Griggs and edited by Stacy Katzman. The budget was $2,000,000.
# Test Output:
# -------------------
# ont_19_film_test_46
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language),
#
# Test Sentence: The English-language film, Super Capers, was edited by Stacy Katzman, and stars Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_47
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography),
#
# Test Sentence: It's Great to Be Young is a 1956 film by Gilbert Taylor's cinematography; it cost 282838 and starred John Mills.
# Test Output:
# -------------------
# ont_19_film_test_48
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: writer(, Person),
#
# Test Sentence: Super Capers was written by the director Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_49
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: deathPlace(Artist, Place),
#
# Test Sentence: The deathplace of John Mills was in Denham, Buckinghamshire.
# Test Output:
# -------------------
# ont_19_film_test_50
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), distributor(Film, Company), runtime(Film, ),
#
# Test Sentence: At a length of 98 minutes, the movie Super Capers starred Michael Rooker and Tom Sizemore. The film was distributed by both Roadside Attractions and Lionsgate.
# Test Output:
# -------------------
# ont_19_film_test_51
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Test Sentence: Adam West had a main role in the movie Super Capers.
# Test Output:
# -------------------
# ont_19_film_test_52
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), distributor(Film, Company), foundingYear(Organisation, ),
#
# Test Sentence: Super Capers was a film starring Justin Whalin distributed by Lionsgate and Roadside Attractions. Attractions was founded in 2003.
# Test Output:
# -------------------
# ont_19_film_test_53
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthDate(Artist, ),
#
# Test Sentence: Michael Rooker was born on April 6th 1955.
# Test Output:
# -------------------
# ont_19_film_test_54
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), distributor(Film, Company),
#
# Test Sentence: Super Capers, distributed by Lionsgate and Roadside Attractions companies, is a movie starring Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_55
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography),
#
# Test Sentence: Cyril Frankel directed the 1956 film It's Great to Be Young which runs 94 minutes and costed £282,838. The movie is starring John Mills and in Gilbert Taylor's cinematography.
# Test Output:
# -------------------
# ont_19_film_test_56
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), gross(Film, ), runtime(Film, ),
#
# Test Sentence: Super Capers is a 98 minute film starring Tom Lister Jr. Directed and written by Ray Griggs, he only made $30,955 from the film.
# Test Output:
# -------------------
# ont_19_film_test_57
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), deathYear(Artist, ), director(Film, Person),
#
# Test Sentence: John Mills, died in 2005, played leading role in the 1956 film It' Great to be young which was directed by Cyril Frankel. Cecil Parker also had a main role in the movie which was written by Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_58
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: type(Film, Type), language(Film, Language), distributor(Film, Company), iso6391Code(Country, ),
#
# Test Sentence: Roadside Attractions and the public company Lionsgate distributed the English-language movie Super Capers with "en" as the ISO 639-1 code.
# Test Output:
# -------------------
# ont_19_film_test_59
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), distributor(Film, Company), runtime(Film, ), starring(Film, Artist), editing(Film, Artist),
#
# Test Sentence: Super Capers is a movie starring Tom Sizemore and Michael Rooker. It’s 98 minutes and plays in English. It is distributed by Lionsgate and Roadside Attractions. Stacy Katzman was the film editor.
# Test Output:
# -------------------
# ont_19_film_test_60
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthYear(Artist, ), writer(, Person), starring(Film, Artist),
#
# Test Sentence: Michael Rooker starring to film Super Capers written by director Ray Griggs born in 1974.
# Test Output:
# -------------------
# ont_19_film_test_61
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), musicComposer(Film, Artist), runtime(Film, ),
#
# Test Sentence: The 1956 movie It's Great to Be Young was directed by Cyril Frankel, composed by Louis Levy, and its length is 94 minutes.
# Test Output:
# -------------------
# ont_19_film_test_62
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), director(Film, Person),
#
# Test Sentence: It's Great to Be Young is a 1956 film which was produced by Cyril Frankel, and starred John Mills and Cecil Parker.
# Test Output:
# -------------------
# ont_19_film_test_63
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Test Sentence: The film Super Capers starred Justin Whalin.
# Test Output:
# -------------------
# ont_19_film_test_64
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: musicComposer(Film, Artist), birthDate(Artist, ),
#
# Test Sentence: Louis Levy, who was born on November 20, 1894, is the music composer for the film "It's Great to be Young."
# Test Output:
# -------------------
# ont_19_film_test_65
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), director(Film, Person),
#
# Test Sentence: Super Capers, which is a movie written and directed by Ray Griggs, starred Danielle Harris.
# Test Output:
# -------------------
# ont_19_film_test_66
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), budget(Film, ), distributor(Film, Company),
#
# Test Sentence: Super Capers is a film that stars Michael Rooker and is distributed by Roadside Attractions and Lionsgate. The budget for the film was $2,000,000.
# Test Output:
# -------------------
# ont_19_film_test_67
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), runtime(Film, ),
#
# Test Sentence: It's Great to Be Young was a film from 1956; its length is 94 minutes. John Mills had a main role in the film which accrued 282,838 pounds at the box office.
# Test Output:
# -------------------
# ont_19_film_test_68
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), gross(Film, ), director(Film, Person),
#
# Test Sentence: Super Capers made $30,955 and starred infamous actor, Adam West. It was written and directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_69
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), language(Film, Language),
#
# Test Sentence: Super Capers, starring Michael Rooker and Tom Sizemore, is a movie in English.
# Test Output:
# -------------------
# ont_19_film_test_70
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language), runtime(Film, ),
#
# Test Sentence: Super Capers is a 98 minute movie starring Michael Rooker and Tom Sizemore. Stacy Katzman edited Super Capers which was filmed in English.
# Test Output:
# -------------------
# ont_19_film_test_71
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), gross(Film, ), musicComposer(Film, Artist), runtime(Film, ),
#
# Test Sentence: It's Great to Be Young is a 1956 film that lasted for 94 minutes. The directors and music composers were Cyril Frankel and Louis Levy. It cost 282,838 pounds to produce the movie.
# Test Output:
# -------------------
# ont_19_film_test_72
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), spokenIn(Language, Country), activeYearsStartYear(Artist, ), starring(Film, Artist),
#
# Test Sentence: Super Capers is a film starring Michael Rooker and Tom Sizemore, who began his career in 1989. The language of the movie Super Capers is English, which is the spoken language in Great Britain.
# Test Output:
# -------------------
# ont_19_film_test_73
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Test Sentence: John Mills had a main role in the 94 minute movie It's Great to Be Young which took 282838 pounds at the box office. Louis Levy composed the music for the movie which had Gilbert Taylor as the cinematographer.
# Test Output:
# -------------------
# ont_19_film_test_74
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), editing(Film, Artist),
#
# Test Sentence: Cecil Parker starred in the 1956 movie It's Great to Be Young which was written by Ted Willis and edited by Max Benedict.
# Test Output:
# -------------------
# ont_19_film_test_75
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), distributor(Film, Company),
#
# Test Sentence: Super Capers, a movie directed by Ray Griggs, was distributed by both Lionsgate and Roadside Attractions and had a 98 minute run time.
# Test Output:
# -------------------
# ont_19_film_test_76
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Test Sentence: The film "It's Great to Be Young" starring John Mills was released in 1956. It was directed by Cyril Frankel and music was composed by Louis Levy. Cinematography is taken care by Gilbert Taylor, and duration of the film is 94 minutes. The film collected 282,838 pounds.
# Test Output:
# ...
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography),
#
# Test Sentence: Released in 1956, the movie It's Great to be Young lasted for 94 minutes and grossed £282,838. The director was Cyril Frankel and Cecil Parker together with John Mills had main roles, whilst Gilbert Taylor was the cinematographer.
# Test Output:
# -------------------
# ont_19_film_test_102
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: activeYearsStartYear(Artist, ),
#
# Test Sentence: Max Benedict began his career in 1947.
# Test Output:
# -------------------
# ont_19_film_test_103
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: spouse(Artist, Person),
#
# Test Sentence: John Mills is the spouse of Mary Hayley Bell.
# Test Output:
# -------------------
# ont_19_film_test_104
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthPlace(Artist, Place),
#
# Test Sentence: Justin Whalin was born in San Francisco.
# Test Output:
# -------------------
# ont_19_film_test_105
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), spouse(Artist, Person),
#
# Test Sentence: It's Great to be Young is a 1956 film starring Cecil Parker and John Mills. Mills was married to Aileen Raymond and Mary Hayley Bell.
# Test Output:
# -------------------
# ont_19_film_test_106
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), starring(Film, Artist), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Test Sentence: In the film It's Great to Be Young, which was filmed in 1956 and lasted 94 minutes, Cyril Frankel was the director, Gilbert Taylor was the cinematographer. The film music composer was Louis Levy, and the main role was portrayed by Cecil Parker.
# Test Output:
# -------------------
# ont_19_film_test_107
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: editing(Film, Artist), musicComposer(Film, Artist), cinematography(Film, Cinematography),
#
# Test Sentence: Louis Levy is the music composer of It's Great to Be Young (1956 film) in Gilbert Taylor's cinematography whereas Max Benedict its editor.
# Test Output:
# -------------------
# ont_19_film_test_108
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), editing(Film, Artist), distributor(Film, Company), runtime(Film, ),
#
# Test Sentence: Super Capers is a 98-minute English-language movie that was edited by Stacy Katzman. It was written by Lionsgate and Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_109
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: occupation(Artist, Occupation),
#
# Test Sentence: Justin Whalin’s job is a presenter.
# Test Output:
# -------------------
# ont_19_film_test_110
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthPlace(Artist, Place),
#
# Test Sentence: Cyril Frankel was born in the UK.
# Test Output:
# -------------------
# ont_19_film_test_111
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Test Sentence: Super Capers is a film starring Tom Lister Jr.
# Test Output:
# -------------------
# ont_19_film_test_112
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), musicComposer(Film, Artist),
#
# Test Sentence: It's Great to be Young is a 1956 film starring John Mills and Cecil Parker. Louis Levy composed the music for the film.
# Test Output:
# -------------------
# ont_19_film_test_113
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person),
#
# Test Sentence: It's Great to Be Young is a 1956 film directed by Cyril Frankel.
# Test Output:
# -------------------
# ont_19_film_test_114
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), occupation(Artist, Occupation),
#
# Test Sentence: Tom Sizemore, who is an actor, stars in Super Capers.
# Test Output:
# -------------------
# ont_19_film_test_115
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), deathPlace(Artist, Place),
#
# Test Sentence: John Mills had a main role in the 1956 film It's Great to Be Young, starring alongside Cecil Parker. Mills died in Denham, Buckinghamshire.
# Test Output:
# -------------------
# ont_19_film_test_116
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthYear(Artist, ),
#
# Test Sentence: Super Capers starred Adam West, who was born in the year 1928.
# Test Output:
# -------------------
# ont_19_film_test_117
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthName(Artist, ), deathPlace(Artist, Place),
#
# Test Sentence: Cecil Parker, also known as Cecil Schwabe, starred in It’s Great to Be Young alongside lead actor John Mills. The movie was released in 1956. Mills passed away in Denham, Buckinghamshire.
# Test Output:
# -------------------
# ont_19_film_test_118
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: occupation(Artist, Occupation),
#
# Test Sentence: Cyril Frankel was a television director.
# Test Output:
# -------------------
# ont_19_film_test_119
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ),
#
# Test Sentence: It's Great to Be Young, which is a 1956 film directed by Cyril Frankel, is 94 minutes in length.
# Test Output:
# -------------------
# ont_19_film_test_120
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: child(Artist, Person),
#
# Test Sentence: Hayley Mills is the child of John Mills.
# Test Output:
# -------------------
# ont_19_film_test_121
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: iso6392Code(City, ),
#
# Test Sentence: The language code (ISO 639-2) of the English language is eng.
# Test Output:
# -------------------
# ont_19_film_test_122
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), writer(, Person), runtime(Film, ), starring(Film, Artist), editing(Film, Artist), budget(Film, ),
#
# Test Sentence: Super Capers, an English-language movie, had a running time of 98 minutes and a 2,000,000 dollar budget. Super Capers was edited by Stacy Katzman, written by Ray Griggs, and starred Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_123
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist),
#
# Test Sentence: Featuring Cecil Parker as a main role, It's Great to Be Young was edited by Max Benedict. The composer of music for the film was Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_124
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), musicComposer(Film, Artist),
#
# Test Sentence: It's Great to Be Young (a 1956 film directed by Cyril Frankel) is 94 minutes long. Louis Levy is the music composer for the film, while Cecil Parker had a main role in the film and Ted Willis is the writer.
# Test Output:
# -------------------
# ont_19_film_test_125
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language), distributor(Film, Company),
#
# Test Sentence: Super Capers is a film starring Michael Rooker and Tom Sizemore.The film was edited by Stacy Katzman, and the language is English. Roadside Attractions is the distributor of the movie.
# Test Output:
# -------------------
# ont_19_film_test_126
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Test Sentence: John Mills is playing the lead in the movie It's Great to Be Young, which was released in 1956.
# Test Output:
# -------------------
# ont_19_film_test_127
# Extract relational triplets from the sentence based on the provided ontology relations.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: distributor(Film, Company), foundedBy(Organisation, Person),
#
# Test Sentence: Super Capers was distributed by Roadside Attractions and Lionsgate (founded by Frank Giustra).
# Test Output:
# -------------------

# %%
output_file_path = os.path.join(output_folder_path, "ont_19_film_n_rels_0_distractor_0_shot_prompts.jsonl")
utils.save_jsonl(zero_shot_prompts, output_file_path)
# Out:
# Saved JSONL data to c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\data\dbpedia_new\n_rels_0_distractors\ont_19_film_n_rels_0_distractor_0_shot_prompts.jsonl

# %% [markdown]
# # generate one shot example prompt

# %%
# read new test file if the previous block was not ran
new_test_file_path = os.path.join(output_folder_path, "ont_19_film_test.jsonl")
tests = utils.load_jsonl(new_test_file_path)
print(tests[0])
# Out:
# {'id': 'ont_19_film_test_1', 'sent': "It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.", 'gt_relations': ['starring', 'writer', 'musicComposer']}

# %%
one_shot_prompts = []
for item in tests:
    prompt_item = {}
    prompt_item["id"] = item["id"]
    # get the similar train sentences for the test sentence
    similar_sents = get_similar_sentences(item["id"], test_train_similarity)
    # we retrieve by default the first similar sentence from the list of similar sentences
    simil_sent_id = similar_sents[0]

    # we get the train sentence from the train sentences list and from there we process each field sub_label, obj_label, rel_label
    train_sent = get_train_sentence(simil_sent_id, train)
    prompt_item["prompt"]= prepare_prompt_one_shot(item["sent"], item["gt_relations"], ontology, train_sent)
    print(prompt_item["id"])
    print(prompt_item["prompt"])
    print("-------------------")
    one_shot_prompts.append(prompt_item)
# Out:
# ont_19_film_test_1
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), musicComposer(Film, Artist),
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_2
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), budget(Film, ),
#
# Example Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: Super Capers is a 98 minute film with a $2000000.0 budget. It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_3
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: Cecil Parker had a main role in It's Great to Be Young.
# Test Output:
# -------------------
# ont_19_film_test_4
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
# Test Sentence: The movie "Super Capers" was directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_5
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: type(Film, Type), distributor(Film, Company),
#
# Example Sentence: McVeagh of the South Seas was distributed by Alliance Films Corporation.
# Example Output: distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
# Test Sentence: Super Capers was distributed by the public company Lionsgate. It was also distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_6
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: John Mills had a main role in the movie It's Great to Be Young which has taken 282,838 pounds at the box office.
# Test Output:
# -------------------
# ont_19_film_test_7
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), runtime(Film, ),
#
# Example Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.
# Example Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0),
#
# Test Sentence: Super Capers, a film written by Ray Griggs, is 98 minutes long. Danielle Harris was one of the stars of the movie.
# Test Output:
# -------------------
# ont_19_film_test_8
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), cinematography(Film, Cinematography),
#
# Example Sentence: The cinematography of English Without Tears was done by Bernard Knowles.
# Example Output: cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: John Mills starred in the 1956 film It’s Great to Be Young which featured cinematography by Gilbert Taylor.
# Test Output:
# -------------------
# ont_19_film_test_9
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), starring(Film, Artist), runtime(Film, ),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
# Test Sentence: The 1956 movie It's Great to Be Young was directed by Cyril Frankel, starred Cecil Parker, and has a running time of 94 minutes.
# Test Output:
# -------------------
# ont_19_film_test_10
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthYear(Artist, ), writer(, Person), starring(Film, Artist),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
# Test Sentence: Director Ray Griggs, born in 1974, is the writer of the film Super Capers, starring Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_11
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: John Mills and Cecil Parker starred in the 1956 movie It's Great to Be Young which runs 94 minutes and had Gilbert Taylor as the cinematographer. The movie costed £282,838.
# Test Output:
# -------------------
# ont_19_film_test_12
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: writer(, Person),
#
# Example Sentence: Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald. The film was directed by Harold French, an actor whose career began in 1920.
# Example Output: director(English_Without_Tears,Harold_French), deathYear(Terence_Rattigan,1977-01-01), activeYearsStartYear(Harold_French,1920-01-01), writer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Terence_Rattigan),
#
# Test Sentence: Writer of the 1956 film It's Great to Be Young is Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_13
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), activeYearsStartYear(Artist, ),
#
# Example Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
# Test Sentence: Tom Sizemore, who began acting in 1989, and Adam West have both starred in Super Capers.
# Test Output:
# -------------------
# ont_19_film_test_14
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: The English-language film Super Capers was edited by Stacy Katzman and played by Michael Rooker.
# Test Output:
# -------------------
# ont_19_film_test_15
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
# Test Sentence: Tom Sizemore stars in Super Capers which starred Michael Rooker.
# Test Output:
# -------------------
# ont_19_film_test_16
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthPlace(Artist, Place),
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
# Test Sentence: Super Capers starred Michael Rooker, who was born in Jasper, Alabama.
# Test Output:
# -------------------
# ont_19_film_test_17
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist), runtime(Film, ),
#
# Example Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: It's great to be young is a movie from 1956 that runs for 94 minutes. It stars Cecil Parker and it’s edited by Max Benedict. Louis Levy composed the music.
# Test Output:
# -------------------
# ont_19_film_test_18
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), musicComposer(Film, Artist), director(Film, Person), runtime(Film, ),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: John Mills played the lead role and Cecil Parker had a main role in the movie It's Great to Be Young. The movie was released in 1956 and had a duration of 94 minutes. Cyril Frankel is the director and Louis Levy is the music composer of the movie.
# Test Output:
# -------------------
# ont_19_film_test_19
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: Gilbert Taylor was the cinematographer while Cyril Frankel was the director of the movie It's Great to Be Young. It came out in 1956 and lasted 94 minutes and accumulated 282,838 pounds.
# Test Output:
# -------------------
# ont_19_film_test_20
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), distributor(Film, Company), starring(Film, Artist), gross(Film, ),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
# Test Sentence: “Super Capers” is a 98-minute-long movie starring Tom Lister Jr. Distributed by Lionsgate, the film grossed $30,955. Ray Griggs was the director of the film.
# Test Output:
# -------------------
# ont_19_film_test_21
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), distributor(Film, Company),
#
# Example Sentence: The movie English Without Tears' released on July 28, 1994. Produced by Anatole de Grunwald, it also featured Nicholas Brodszky's music compositions while he also worked as part of the non-performing staff.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), producer(English_Without_Tears,Anatole_de_Grunwald), musicComposer(English_Without_Tears,Nicholas_Brodszky), background(Nicholas_Brodszky,non_performing_personnel),
#
# Test Sentence: The film Super Capers, distributed by Lionsgate and starring Justin Whalin, grossed $30,955.
# Test Output:
# -------------------
# ont_19_film_test_22
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ),
#
# Example Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.
# Example Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0),
#
# Test Sentence: Super Capers, a film that had a running time of 98 minutes, stars Justin Whalin.
# Test Output:
# -------------------
# ont_19_film_test_23
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthDate(Artist, ), birthPlace(Artist, Place),
#
# Example Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
# Test Sentence: Super Capers stars the actors Justin Whalin and Michael Rooker. Whalin was born in San Francisco and while the birth location of Rooker is unknown, he was born on April 6th, 1955.
# Test Output:
# -------------------
# ont_19_film_test_24
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: Ted Willis wrote “It’s great to be young” a 1956 film starring Cecil Parker.
# Test Output:
# -------------------
# ont_19_film_test_25
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), budget(Film, ), director(Film, Person),
#
# Example Sentence: Harry Carey, born in 1878, wrote, directed and acted in the film McVeagh of the South Seas which was produced by the Progressive Motion Picture Company. Cyril Bruce also directed the movie which was distributed by Alliance Films Corporation.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
# Test Sentence: Super Capers, whose budget was 2000000, was lead by Adam West, and both written and directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_26
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: It's Great to Be Young is a 1956 film in which John Mills played a lead role. The film featured Gilbert Taylor as a cinematographer, and it received £282,838. The duration of the film is around 94 minutes.
# Test Output:
# -------------------
# ont_19_film_test_27
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: The popular 1956 film, It's Great to Be Young, starred English actors John Mills and Cecil Parker, and was directed by Cyril Frankel. Cinematography was by Gilbert Taylor, with composition for the musical comedy by Louis Levy. The film's running time is 94 minutes, and, according to the Historical Journal of Film, Radio and Television, was produced for 282,838 pounds.
# Test Output:
# -------------------
# ont_19_film_test_28
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: cinematography(Film, Cinematography),
#
# Example Sentence: English Without Tears was edited by Alan Jaggs, produced by Anatole de Grunwald, with Bernard Knowles as the cinematographer.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: It's Great to Be Young had Gilbert Taylor as cinematographer.
# Test Output:
# -------------------
# ont_19_film_test_29
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), distributor(Film, Company), runtime(Film, ),
#
# Example Sentence: Harry Carey born in 1878 is starring in the film McVeagh of the South Seas, registered in IMDb with the ID 0004319. The film was produced by Progressive Motion Picture Company.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company),
#
# Test Sentence: Tom Sizemore starred in the 98.0 minutes long movie Super Capers which was distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_30
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), director(Film, Person), runtime(Film, ),
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: It's Great to Be Young, a 1956 film directed by Cyril Frankel, received £282,838. John Mills plays the lead in this 94-minute long movie.
# Test Output:
# -------------------
# ont_19_film_test_31
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), editing(Film, Artist), activeYearsStartYear(Artist, ), runtime(Film, ),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
# Test Sentence: It's Great to Be Young (1956, 94 minutes) is a film edited by Max Benedict, who has been active in the film industry since 1947. The director of the movie is Cyril Frankel.
# Test Output:
# -------------------
# ont_19_film_test_32
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: spouse(Artist, Person),
#
# Example Sentence: McVeagh of the South Seas is a film directed by Cyril Bruce and Harry Carey. It’s a film that is logged in the IMDb database with the ID of 0004319. Carey was born on 1878 and was the writer of the film while he played a major character in the movie too. This movie was distributed by Alliance Films Corporation.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
# Test Sentence: Tom Sizemore was married to Maeve Quinlan.
# Test Output:
# -------------------
# ont_19_film_test_33
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), gross(Film, ), cinematography(Film, Cinematography), musicComposer(Film, Artist),
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: It’s Great to Be Young is a 1956 film that lasts 94 minutes. It was directed by Cyril Frankel and its writer was Ted Willis. John Mills played in the film, and it collected 282,838 at the box office. The film music was written by Louis Levy, and Gilbert Taylor served as a cinematographer.
# Test Output:
# -------------------
# ont_19_film_test_34
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: distributor(Film, Company),
#
# Example Sentence: Roadside Attractions is founded in 2003.
# Example Output: foundingYear(Roadside_Attractions,2003-01-01),
#
# Test Sentence: Distributor of the movie Super Capers is Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_35
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), musicComposer(Film, Artist), runtime(Film, ),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
# Test Sentence: The 1956 film 'It's great to be young', directed by Cyril Frankel, is 94 minutes long. The music was composed by Louis Levy, while the writer is Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_36
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), distributor(Film, Company), runtime(Film, ), starring(Film, Artist), editing(Film, Artist),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: Super Capers is a 98.0 minute long English-language film starring Michael Rooker and Tom Sizemore. The film was edited by Stacy Katzman and distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_37
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthPlace(Artist, Place),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: It's Great to Be Young (1956) stars John Mills, who was born in North Elmham.
# Test Output:
# -------------------
# ont_19_film_test_38
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), editing(Film, Artist), musicComposer(Film, Artist), deathYear(Artist, ),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
# Test Sentence: The 1956 movie , It's Great to be Young, was edited by Max Benedict who later died in 1986. The director was Cyril Frankel and the music composer was Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_39
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: writer(, Person), runtime(Film, ), starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist),
#
# Example Sentence: English Without Tears is a 89 minute film that was written and produced by Anatole de Grunwald. the movie was released on July 28th, 1944. Nicholas Brodszky was the musical composer and Harold French was the director . The editing was done by Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: It's Great to Be Young is a 1956 film that stars Cecil Parker and John Mills. The length of the movie is 94 minutes and written by Ted Willis. It’s edited by Max Benedict and the score is composed by Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_40
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthYear(Artist, ),
#
# Example Sentence: Adam West got his first role in 1954.
# Example Output: activeYearsStartYear(Adam_West,1954-01-01),
#
# Test Sentence: Michael Rooker was born in the year 1955.
# Test Output:
# -------------------
# ont_19_film_test_41
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: activeYearsStartYear(Artist, ),
#
# Example Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.
# Example Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0),
#
# Test Sentence: Tom Sizemore began his career in 1989.
# Test Output:
# -------------------
# ont_19_film_test_42
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), starring(Film, Artist),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: Cecil Parker starred in the 1956 movie It's Great to Be Young, directed by Cyril Frankel.
# Test Output:
# -------------------
# ont_19_film_test_43
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: keyPerson(Organisation, Person),
#
# Example Sentence: Cyril Bruce directed Harry Carey in McVeagh of the South Seas, a film produced by the Progressive Motion Picture Company.
# Example Output: starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), director(McVeagh_of_the_South_Seas,Cyril_Bruce),
#
# Test Sentence: Michael R Burns plays an important role for the company Lionsgate.
# Test Output:
# -------------------
# ont_19_film_test_44
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: gross(Film, ), budget(Film, ), runtime(Film, ),
#
# Example Sentence: The movie English Without Tears' released on July 28, 1994. Produced by Anatole de Grunwald, it also featured Nicholas Brodszky's music compositions while he also worked as part of the non-performing staff.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), producer(English_Without_Tears,Anatole_de_Grunwald), musicComposer(English_Without_Tears,Nicholas_Brodszky), background(Nicholas_Brodszky,non_performing_personnel),
#
# Test Sentence: The film Super Capers is 98 minutes long. The budget was 2,000,000 but the gross income was only $30,955.
# Test Output:
# -------------------
# ont_19_film_test_45
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), writer(, Person), distributor(Film, Company), runtime(Film, ), editing(Film, Artist), budget(Film, ),
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# ...
# Test Output:
# -------------------
# ont_19_film_test_110
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthPlace(Artist, Place),
#
# Example Sentence: Harold French is born in the UK.
# Example Output: birthPlace(Harold_French,UK),
#
# Test Sentence: Cyril Frankel was born in the UK.
# Test Output:
# -------------------
# ont_19_film_test_111
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: Terence Rattigan is registered in IMDb under the ID 0711905.
# Example Output: imdbId(Terence_Rattigan,0711905),
#
# Test Sentence: Super Capers is a film starring Tom Lister Jr.
# Test Output:
# -------------------
# ont_19_film_test_112
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), musicComposer(Film, Artist),
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: It's Great to be Young is a 1956 film starring John Mills and Cecil Parker. Louis Levy composed the music for the film.
# Test Output:
# -------------------
# ont_19_film_test_113
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person),
#
# Example Sentence: English Without Tears is a film directed by Harold French.
# Example Output: director(English_Without_Tears,Harold_French),
#
# Test Sentence: It's Great to Be Young is a 1956 film directed by Cyril Frankel.
# Test Output:
# -------------------
# ont_19_film_test_114
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), occupation(Artist, Occupation),
#
# Example Sentence: Harry Carey born in 1878 is starring in the film McVeagh of the South Seas, registered in IMDb with the ID 0004319. The film was produced by Progressive Motion Picture Company.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company),
#
# Test Sentence: Tom Sizemore, who is an actor, stars in Super Capers.
# Test Output:
# -------------------
# ont_19_film_test_115
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), deathPlace(Artist, Place),
#
# Example Sentence: John Mills died in 2005.
# Example Output: deathYear(John_Mills,2005),
#
# Test Sentence: John Mills had a main role in the 1956 film It's Great to Be Young, starring alongside Cecil Parker. Mills died in Denham, Buckinghamshire.
# Test Output:
# -------------------
# ont_19_film_test_116
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthYear(Artist, ),
#
# Example Sentence: Adam West was born in the year 1928.
# Example Output: birthYear(Adam_West,1928),
#
# Test Sentence: Super Capers starred Adam West, who was born in the year 1928.
# Test Output:
# -------------------
# ont_19_film_test_117
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthName(Artist, ), deathPlace(Artist, Place),
#
# Example Sentence: Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald. The film was directed by Harold French, an actor whose career began in 1920.
# Example Output: director(English_Without_Tears,Harold_French), deathYear(Terence_Rattigan,1977-01-01), activeYearsStartYear(Harold_French,1920-01-01), writer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Terence_Rattigan),
#
# Test Sentence: Cecil Parker, also known as Cecil Schwabe, starred in It’s Great to Be Young alongside lead actor John Mills. The movie was released in 1956. Mills passed away in Denham, Buckinghamshire.
# Test Output:
# -------------------
# ont_19_film_test_118
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: occupation(Artist, Occupation),
#
# Example Sentence: Harold French is a film director.
# Example Output: occupation(Harold_French,Film_director),
#
# Test Sentence: Cyril Frankel was a television director.
# Test Output:
# -------------------
# ont_19_film_test_119
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ),
#
# Example Sentence: English Without Tears, written by Terence Rattigan, runs 89 minutes. The cinematography for the film was done by Bernard Knowles.
# Example Output: cinematography(English_Without_Tears,Bernard_Knowles), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0),
#
# Test Sentence: It's Great to Be Young, which is a 1956 film directed by Cyril Frankel, is 94 minutes in length.
# Test Output:
# -------------------
# ont_19_film_test_120
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: child(Artist, Person),
#
# Example Sentence: John Mills died in 2005.
# Example Output: deathYear(John_Mills,2005),
#
# Test Sentence: Hayley Mills is the child of John Mills.
# Test Output:
# -------------------
# ont_19_film_test_121
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: iso6392Code(City, ),
#
# Example Sentence: English Without Tears is an 89 minute movie written by Terence Rattigan and released on July 28th, 1944. Alan Jaggs was the editor while Nicholas Brodszky wrote the music for the film.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0), editing(English_Without_Tears,Alan_Jaggs), musicComposer(English_Without_Tears,Nicholas_Brodszky),
#
# Test Sentence: The language code (ISO 639-2) of the English language is eng.
# Test Output:
# -------------------
# ont_19_film_test_122
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), writer(, Person), runtime(Film, ), starring(Film, Artist), editing(Film, Artist), budget(Film, ),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: Super Capers, an English-language movie, had a running time of 98 minutes and a 2,000,000 dollar budget. Super Capers was edited by Stacy Katzman, written by Ray Griggs, and starred Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_123
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist),
#
# Example Sentence: The film English Without Tears (89 minutes long) features music composed by Nicholas Brodszky. English Without Tears was edited by Alan Jaggs, and the film's cinematography was done by Bernard Knowles.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), editing(English_Without_Tears,Alan_Jaggs), runtime(English_Without_Tears,89.0), cinematography(English_Without_Tears,Bernard_Knowles),
#
# Test Sentence: Featuring Cecil Parker as a main role, It's Great to Be Young was edited by Max Benedict. The composer of music for the film was Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_124
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), musicComposer(Film, Artist),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
# Test Sentence: It's Great to Be Young (a 1956 film directed by Cyril Frankel) is 94 minutes long. Louis Levy is the music composer for the film, while Cecil Parker had a main role in the film and Ted Willis is the writer.
# Test Output:
# -------------------
# ont_19_film_test_125
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language), distributor(Film, Company),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
# Test Sentence: Super Capers is a film starring Michael Rooker and Tom Sizemore.The film was edited by Stacy Katzman, and the language is English. Roadside Attractions is the distributor of the movie.
# Test Output:
# -------------------
# ont_19_film_test_126
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: Adam West got his first role in 1954.
# Example Output: activeYearsStartYear(Adam_West,1954-01-01),
#
# Test Sentence: John Mills is playing the lead in the movie It's Great to Be Young, which was released in 1956.
# Test Output:
# -------------------
# ont_19_film_test_127
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: distributor(Film, Company), foundedBy(Organisation, Person),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
# Test Sentence: Super Capers was distributed by Roadside Attractions and Lionsgate (founded by Frank Giustra).
# Test Output:
# -------------------

# %%
output_file_path = os.path.join(output_folder_path, "ont_19_film_n_rels_0_distractor_1_shot_prompts.jsonl")
utils.save_jsonl(one_shot_prompts, output_file_path)
# Out:
# Saved JSONL data to c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\data\dbpedia_new\n_rels_0_distractors\ont_19_film_n_rels_0_distractor_1_shot_prompts.jsonl

# %% [markdown]
# # generate three-shot examples prompt and save

# %%
three_shot_prompts = []
for item in tests:
    prompt_item = {}
    prompt_item["id"] = item["id"]
    # get the similar train sentences for the test sentence
    similar_sents = get_similar_sentences(item["id"], test_train_similarity)
    # we retrieve by default the first three similar sentence from the list of similar sentences
    simil_sent_id = similar_sents[0:3]
    prompt_item["prompt"]= prepare_prompt_three_shot(item["sent"], item["gt_relations"], ontology, simil_sent_id, train)
    print(prompt_item["id"])
    print(prompt_item["prompt"])
    print("-------------------")
    three_shot_prompts.append(prompt_item)
# Out:
# ont_19_film_test_1
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), musicComposer(Film, Artist),
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is a 89 minute film that was written and produced by Anatole de Grunwald. the movie was released on July 28th, 1944. Nicholas Brodszky was the musical composer and Harold French was the director . The editing was done by Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_2
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), budget(Film, ),
#
# Example Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: McVeagh of the South Seas is a film directed by Cyril Bruce and Harry Carey. It’s a film that is logged in the IMDb database with the ID of 0004319. Carey was born on 1878 and was the writer of the film while he played a major character in the movie too. This movie was distributed by Alliance Films Corporation.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Test Sentence: Super Capers is a 98 minute film with a $2000000.0 budget. It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_3
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: Harry Carey, born in 1878, wrote, directed and acted in the film McVeagh of the South Seas which was produced by the Progressive Motion Picture Company. Cyril Bruce also directed the movie which was distributed by Alliance Films Corporation.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: Anatole de Grunwald produced and Harold French directed English Without Tears. The songs used in the movie were composed by Nicholas Brodszky, and Bernard Knowles was in charge of the cinematography.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), cinematography(English_Without_Tears,Bernard_Knowles), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: Cecil Parker had a main role in It's Great to Be Young.
# Test Output:
# -------------------
# ont_19_film_test_4
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Example Sentence: "McVeagh of the South Seas" is distributed by Alliance Films Corporation and has the IMDb id of 0004319. It’s directed by Harry Carey and Gregory Allen. Carey was born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen), imdbId(McVeagh_of_the_South_Seas,0004319),
#
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: The movie "Super Capers" was directed by Ray Griggs.
# Test Output:
# -------------------
# ont_19_film_test_5
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: type(Film, Type), distributor(Film, Company),
#
# Example Sentence: McVeagh of the South Seas was distributed by Alliance Films Corporation.
# Example Output: distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: Super Capers was distributed by the public company Lionsgate. It was also distributed by Roadside Attractions.
# Test Output:
# -------------------
# ont_19_film_test_6
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: The movie English Without Tears' released on July 28, 1994. Produced by Anatole de Grunwald, it also featured Nicholas Brodszky's music compositions while he also worked as part of the non-performing staff.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), producer(English_Without_Tears,Anatole_de_Grunwald), musicComposer(English_Without_Tears,Nicholas_Brodszky), background(Nicholas_Brodszky,non_performing_personnel),
#
#
# Test Sentence: John Mills had a main role in the movie It's Great to Be Young which has taken 282,838 pounds at the box office.
# Test Output:
# -------------------
# ont_19_film_test_7
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person), runtime(Film, ),
#
# Example Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.
# Example Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0),
#
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Example Sentence: English Without Tears, written by Terence Rattigan, runs 89 minutes. The cinematography for the film was done by Bernard Knowles.
# Example Output: cinematography(English_Without_Tears,Bernard_Knowles), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0),
#
#
# Test Sentence: Super Capers, a film written by Ray Griggs, is 98 minutes long. Danielle Harris was one of the stars of the movie.
# Test Output:
# -------------------
# ont_19_film_test_8
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), cinematography(Film, Cinematography),
#
# Example Sentence: The cinematography of English Without Tears was done by Bernard Knowles.
# Example Output: cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: Anatole de Grunwald's English Without tears cinematography was done by Bernard Knowles.
# Example Output: writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: English Without Tears was edited by Alan Jaggs, produced by Anatole de Grunwald, with Bernard Knowles as the cinematographer.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Test Sentence: John Mills starred in the 1956 film It’s Great to Be Young which featured cinematography by Gilbert Taylor.
# Test Output:
# -------------------
# ont_19_film_test_9
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), starring(Film, Artist), runtime(Film, ),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
#
# Example Sentence: English Without Tears, written by Terence Rattigan, runs 89 minutes. The cinematography for the film was done by Bernard Knowles.
# Example Output: cinematography(English_Without_Tears,Bernard_Knowles), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0),
#
#
# Example Sentence: English Without Tears, a film directed by Harold French and composed by Nicholas Brodszky, was released on 07-28-1944. The film length is 89 minutes.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French),
#
#
# Test Sentence: The 1956 movie It's Great to Be Young was directed by Cyril Frankel, starred Cecil Parker, and has a running time of 94 minutes.
# Test Output:
# -------------------
# ont_19_film_test_10
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: birthYear(Artist, ), writer(, Person), starring(Film, Artist),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Example Sentence: McVeagh of the South Seas is a film directed by Cyril Bruce and Harry Carey. It’s a film that is logged in the IMDb database with the ID of 0004319. Carey was born on 1878 and was the writer of the film while he played a major character in the movie too. This movie was distributed by Alliance Films Corporation.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: Harry Carey, born in 1878, wrote, directed and acted in the film McVeagh of the South Seas which was produced by the Progressive Motion Picture Company. Cyril Bruce also directed the movie which was distributed by Alliance Films Corporation.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: Director Ray Griggs, born in 1974, is the writer of the film Super Capers, starring Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_11
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Test Sentence: John Mills and Cecil Parker starred in the 1956 movie It's Great to Be Young which runs 94 minutes and had Gilbert Taylor as the cinematographer. The movie costed £282,838.
# Test Output:
# -------------------
# ont_19_film_test_12
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: writer(, Person),
#
# Example Sentence: Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald. The film was directed by Harold French, an actor whose career began in 1920.
# Example Output: director(English_Without_Tears,Harold_French), deathYear(Terence_Rattigan,1977-01-01), activeYearsStartYear(Harold_French,1920-01-01), writer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Terence_Rattigan),
#
#
# Example Sentence: Harry Carey (actor, born in 1878) was the writer of the film McVeagh of the South Seas, directed by Cyril Bruce.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
#
# Example Sentence: Anatole de Grunwald wrote and produced English Without Tears which had Bernard Knowles as the cinematographer.
# Example Output: producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Test Sentence: Writer of the 1956 film It's Great to Be Young is Ted Willis.
# Test Output:
# -------------------
# ont_19_film_test_13
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), activeYearsStartYear(Artist, ),
#
# Example Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
#
# Example Sentence: Adam West got his first role in 1954.
# Example Output: activeYearsStartYear(Adam_West,1954-01-01),
#
#
# Example Sentence: Directed by Cyril Bruce, McVeagh of the South Seas stars actor Harry Carey, who was born in eighteen seventy-eight.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
#
# Test Sentence: Tom Sizemore, who began acting in 1989, and Adam West have both starred in Super Capers.
# Test Output:
# -------------------
# ont_19_film_test_14
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: "English Without Tears" was produced and written by Anatole de Grunwald. The editor for the film was Alan Jaggs.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: The editing of the movie English Without Tears was done by Alan Jaggs.
# Example Output: editing(English_Without_Tears,Alan_Jaggs),
#
#
# Test Sentence: The English-language film Super Capers was edited by Stacy Katzman and played by Michael Rooker.
# Test Output:
# -------------------
# ont_19_film_test_15
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
#
# Example Sentence: Harry Carey, born in 1878, wrote, directed and acted in the film McVeagh of the South Seas which was produced by the Progressive Motion Picture Company. Cyril Bruce also directed the movie which was distributed by Alliance Films Corporation.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: McVeagh of the South Seas (IMDb ID 0004319) is a film starring Harry Carey and was directed by Harry Carey and Cyril Bruce.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
#
# Test Sentence: Tom Sizemore stars in Super Capers which starred Michael Rooker.
# Test Output:
# -------------------
# ont_19_film_test_16
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthPlace(Artist, Place),
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: McVeagh of the South Seas is a film directed by Cyril Bruce and Harry Carey. It’s a film that is logged in the IMDb database with the ID of 0004319. Carey was born on 1878 and was the writer of the film while he played a major character in the movie too. This movie was distributed by Alliance Films Corporation.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: McVeagh of the South Seas (IMDb id 0004319) was written by Harry Carey, born in 1878, who also had a role in the film. McVeagh of the South Seas was produced by the Progressive Motion Picture Company and distributed by the Alliance Films Corporation.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: Super Capers starred Michael Rooker, who was born in Jasper, Alabama.
# Test Output:
# -------------------
# ont_19_film_test_17
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist), runtime(Film, ),
#
# Example Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears, a film directed by Harold French and composed by Nicholas Brodszky, was released on 07-28-1944. The film length is 89 minutes.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French),
#
#
# Test Sentence: It's great to be young is a movie from 1956 that runs for 94 minutes. It stars Cecil Parker and it’s edited by Max Benedict. Louis Levy composed the music.
# Test Output:
# -------------------
# ont_19_film_test_18
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), musicComposer(Film, Artist), director(Film, Person), runtime(Film, ),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is a 89 minute film that was written and produced by Anatole de Grunwald. the movie was released on July 28th, 1944. Nicholas Brodszky was the musical composer and Harold French was the director . The editing was done by Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: John Mills played the lead role and Cecil Parker had a main role in the movie It's Great to Be Young. The movie was released in 1956 and had a duration of 94 minutes. Cyril Frankel is the director and Louis Levy is the music composer of the movie.
# Test Output:
# -------------------
# ont_19_film_test_19
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), gross(Film, ), cinematography(Film, Cinematography),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: Anatole de Grunwald wrote and produced the 89 minute movie English Without Tears which was edited by Alan Jaggs and had Bernard Knowles as the cinematographer.
# Example Output: runtime(English_Without_Tears,89.0), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
#
# Test Sentence: Gilbert Taylor was the cinematographer while Cyril Frankel was the director of the movie It's Great to Be Young. It came out in 1956 and lasted 94 minutes and accumulated 282,838 pounds.
# Test Output:
# -------------------
# ont_19_film_test_20
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), runtime(Film, ), distributor(Film, Company), starring(Film, Artist), gross(Film, ),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: “Super Capers” is a 98-minute-long movie starring Tom Lister Jr. Distributed by Lionsgate, the film grossed $30,955. Ray Griggs was the director of the film.
# Test Output:
# -------------------
# ont_19_film_test_21
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), gross(Film, ), distributor(Film, Company),
#
# Example Sentence: The movie English Without Tears' released on July 28, 1994. Produced by Anatole de Grunwald, it also featured Nicholas Brodszky's music compositions while he also worked as part of the non-performing staff.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), producer(English_Without_Tears,Anatole_de_Grunwald), musicComposer(English_Without_Tears,Nicholas_Brodszky), background(Nicholas_Brodszky,non_performing_personnel),
#
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: The film Super Capers, distributed by Lionsgate and starring Justin Whalin, grossed $30,955.
# Test Output:
# -------------------
# ont_19_film_test_22
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), runtime(Film, ),
#
# Example Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.
# Example Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0),
#
#
# Example Sentence: The movie English Without Tears' released on July 28, 1994. Produced by Anatole de Grunwald, it also featured Nicholas Brodszky's music compositions while he also worked as part of the non-performing staff.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), producer(English_Without_Tears,Anatole_de_Grunwald), musicComposer(English_Without_Tears,Nicholas_Brodszky), background(Nicholas_Brodszky,non_performing_personnel),
#
#
# Example Sentence: "English Without Tears", which was written by Anatole de Grunwald, has a running time of 89 minutes.
# Example Output: writer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0),
#
#
# Test Sentence: Super Capers, a film that had a running time of 98 minutes, stars Justin Whalin.
# Test Output:
# -------------------
# ont_19_film_test_23
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), birthDate(Artist, ), birthPlace(Artist, Place),
#
# Example Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.
# Example Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)),
#
#
# Example Sentence: McVeagh of the South Seas is a film directed by Cyril Bruce and Harry Carey. It’s a film that is logged in the IMDb database with the ID of 0004319. Carey was born on 1878 and was the writer of the film while he played a major character in the movie too. This movie was distributed by Alliance Films Corporation.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: Super Capers stars the actors Justin Whalin and Michael Rooker. Whalin was born in San Francisco and while the birth location of Rooker is unknown, he was born on April 6th, 1955.
# Test Output:
# -------------------
# ont_19_film_test_24
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), writer(, Person),
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald. The film was directed by Harold French, an actor whose career began in 1920.
# Example Output: director(English_Without_Tears,Harold_French), deathYear(Terence_Rattigan,1977-01-01), activeYearsStartYear(Harold_French,1920-01-01), writer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Terence_Rattigan),
#
#
# Example Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# ...
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
#
# Test Sentence: It's Great to Be Young, which is a 1956 film directed by Cyril Frankel, is 94 minutes in length.
# Test Output:
# -------------------
# ont_19_film_test_120
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: child(Artist, Person),
#
# Example Sentence: John Mills died in 2005.
# Example Output: deathYear(John_Mills,2005),
#
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.
# Example Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: Hayley Mills is the child of John Mills.
# Test Output:
# -------------------
# ont_19_film_test_121
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: iso6392Code(City, ),
#
# Example Sentence: English Without Tears is an 89 minute movie written by Terence Rattigan and released on July 28th, 1944. Alan Jaggs was the editor while Nicholas Brodszky wrote the music for the film.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0), editing(English_Without_Tears,Alan_Jaggs), musicComposer(English_Without_Tears,Nicholas_Brodszky),
#
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: The language code (ISO 639-2) of the English language is eng.
# Test Output:
# -------------------
# ont_19_film_test_122
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: language(Film, Language), writer(, Person), runtime(Film, ), starring(Film, Artist), editing(Film, Artist), budget(Film, ),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is an 89 minute movie written by Terence Rattigan and released on July 28th, 1944. Alan Jaggs was the editor while Nicholas Brodszky wrote the music for the film.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0), editing(English_Without_Tears,Alan_Jaggs), musicComposer(English_Without_Tears,Nicholas_Brodszky),
#
#
# Example Sentence: English Without Tears, written by Terence Rattigan, runs 89 minutes. The cinematography for the film was done by Bernard Knowles.
# Example Output: cinematography(English_Without_Tears,Bernard_Knowles), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0),
#
#
# Test Sentence: Super Capers, an English-language movie, had a running time of 98 minutes and a 2,000,000 dollar budget. Super Capers was edited by Stacy Katzman, written by Ray Griggs, and starred Michael Rooker and Tom Sizemore.
# Test Output:
# -------------------
# ont_19_film_test_123
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), musicComposer(Film, Artist),
#
# Example Sentence: The film English Without Tears (89 minutes long) features music composed by Nicholas Brodszky. English Without Tears was edited by Alan Jaggs, and the film's cinematography was done by Bernard Knowles.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), editing(English_Without_Tears,Alan_Jaggs), runtime(English_Without_Tears,89.0), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: Anatole de Grunwald produced and Harold French directed English Without Tears. The songs used in the movie were composed by Nicholas Brodszky, and Bernard Knowles was in charge of the cinematography.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), cinematography(English_Without_Tears,Bernard_Knowles), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: Featuring Cecil Parker as a main role, It's Great to Be Young was edited by Max Benedict. The composer of music for the film was Louis Levy.
# Test Output:
# -------------------
# ont_19_film_test_124
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: director(Film, Person), writer(, Person), runtime(Film, ), starring(Film, Artist), musicComposer(Film, Artist),
#
# Example Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs),
#
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is a 89 minute film that was written and produced by Anatole de Grunwald. the movie was released on July 28th, 1944. Nicholas Brodszky was the musical composer and Harold French was the director . The editing was done by Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: It's Great to Be Young (a 1956 film directed by Cyril Frankel) is 94 minutes long. Louis Levy is the music composer for the film, while Cecil Parker had a main role in the film and Ted Willis is the writer.
# Test Output:
# -------------------
# ont_19_film_test_125
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist), editing(Film, Artist), language(Film, Language), distributor(Film, Company),
#
# Example Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.
# Example Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is a film directed and edited by Alan Jaggs and Harold French. Anatole de Grunwald produced the movie while Nicholas Brodszky composed the film.
# Example Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Example Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: Super Capers is a film starring Michael Rooker and Tom Sizemore.The film was edited by Stacy Katzman, and the language is English. Roadside Attractions is the distributor of the movie.
# Test Output:
# -------------------
# ont_19_film_test_126
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: starring(Film, Artist),
#
# Example Sentence: Adam West got his first role in 1954.
# Example Output: activeYearsStartYear(Adam_West,1954-01-01),
#
#
# Example Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.
# Example Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles),
#
#
# Example Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.
# Example Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald),
#
#
# Test Sentence: John Mills is playing the lead in the movie It's Great to Be Young, which was released in 1956.
# Test Output:
# -------------------
# ont_19_film_test_127
# Extract relational triplets from the sentence based on the provided ontology relations and examples.
# Use only the listed relations and ensure subjects and objects align with their specified restrictions.
# Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments.
#
# CONTEXT:
#
#
# Ontology Relations: distributor(Film, Company), foundedBy(Organisation, Person),
#
# Example Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.
# Example Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen),
#
#
# Example Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.
# Example Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Example Sentence: McVeagh of the South Seas was distributed by Alliance Films Corporation.
# Example Output: distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation),
#
#
# Test Sentence: Super Capers was distributed by Roadside Attractions and Lionsgate (founded by Frank Giustra).
# Test Output:
# -------------------

# %%
output_file_path = os.path.join(output_folder_path, "ont_19_film_n_rels_0_distractor_3_shot_prompts.jsonl")
utils.save_jsonl(three_shot_prompts, output_file_path)
# Out:
# Saved JSONL data to c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\data\dbpedia_new\n_rels_0_distractors\ont_19_film_n_rels_0_distractor_3_shot_prompts.jsonl

# %% [markdown]
# # generate baseline relations with one shot prompt
# ### the instruct is changed, the onto class is removed, only keep the baseline onto relations and example

# %%
output_folder_path = os.path.join(dbpedia_new_dir, "baseline_rels")
os.makedirs(output_folder_path, exist_ok=True)  # Will not throw an error if the folder exists

# %%
def get_concept_label(ontology, concept):
    """
    Get the label for the ontology concept
    :param ontology: ontology with concepts ids and labels
    :param ont_dom: input concept ID
    :return: the label of the input concept
    """
    for onto in ontology['concepts']:
        if onto['qid'] == concept:
            return onto['label']
        
        
def get_ontology_relations(ontology):
    """
    Generate a verbalized list of relations in the given ontology to be included in the prompt
    :param ontology:  an ontology as a dictionary
    :return: A string for ontology relations.
            e.g. cast_member(film,human), director (film,human), screenwriter(film,human), producer(film,human), ...
    """

    ont_rels = ""
    onto_rel_strings = list()
    for onto in ontology['relations']:
        ont_rel = onto['label']
        ont_rel = ont_rel.replace(" ", "_")
        ont_dom = onto['domain']
        ont_range = onto['range']
        ont_domain = get_concept_label(ontology, ont_dom)
        ont_range = get_concept_label(ontology, ont_range)

        if ont_rel == None:
            continue
        if ont_domain == None:
            ont_domain = ""
        if ont_range == None:
            ont_range = ""

        onto_rel_strings.append(f"{ont_rel} ({ont_domain},{ont_range})\n")

        ont_rels += ont_rel + "(" + ont_domain + "," + ont_range + "), "

    return ont_rels[0:-2]


def get_similar_sentences(test_sentence_id, test_similar):
    for sim in test_similar:
        if sim == test_sentence_id:
            return test_similar[sim]


def get_train_sentence(simil_sent_id, train_sentences):
    for sent in train_sentences:
        if sent['id'] == simil_sent_id:
            return sent


def get_example_prompt(train_sent):
    example_prompt = "\n\nExample Sentence: " + train_sent['sent']
    
    # Extracting the first triple from the list of triples
    triples = train_sent['triples']

    triples_string = ""
    for triple in triples:
        # Constructing the string representation of each triple
        triples_string += triple['rel'] + "(" + triple['sub'] + "," + triple['obj'] + ")" + ", "
    
    # Constructing the example output based on the new format
    example_prompt += "\nExample Output: " + triples_string 
    
    return example_prompt


def get_test_prompt(test_sentence):
    test_prompt = "\n\nTest Sentence: " + test_sentence
    test_prompt += "\nTest Output: "
    return test_prompt


def prepare_prompt(ontology: dict, test_sentence: str, train_sent: str) -> str:

    prompt_fixed = '''Extract relational triplets from the sentence based on the provided ontology relations and examples.
Use only the listed relations and ensure subjects and objects align with their specified restrictions.
Only return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n
'''

    prompt = prompt_fixed
    prompt += 'CONTEXT:\n\n'
    prompt += '\nOntology Relations: '
    prompt += get_ontology_relations(ontology)
    prompt += get_example_prompt(train_sent)
    prompt += get_test_prompt(test_sentence)

    return prompt

# %%
baseline_one_shot_prompts = []
for test_sentence in tests:
            test_sentence_id = test_sentence['id']
            # test sentence for which the prompt to be generated
            test_sentence = test_sentence['sent']

            # get the similar train sentences for the test sentence
            similar_sents = get_similar_sentences(test_sentence_id, test_train_similarity)
            # we retrieve by default the first similar sentence from the list of similar sentences
            simil_sent_id = similar_sents[0]

            # we get the train sentence from the train sentences list and from there we process each field sub_label, obj_label, rel_label
            train_sent = get_train_sentence(simil_sent_id, train)

            # prompt generation logic
            prompt = prepare_prompt(ontology, test_sentence, train_sent)
            prompt_data = {'id': test_sentence_id, 'prompt': prompt}
            baseline_one_shot_prompts.append(prompt_data)
            print(prompt_data)
# Out:
# {'id': 'ont_19_film_test_1', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Released on 28th July 1944 the 89 minutes long film, "English Without Tears, " was directed by Harold French, produced by Anatole de Grunwald, while the songs in the film were composed by Nicholas Brodszky.\nExample Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: It\'s Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.\nTest Output: '}
# {'id': 'ont_19_film_test_2', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.\nExample Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: Super Capers is a 98 minute film with a $2000000.0 budget. It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.\nTest Output: '}
# {'id': 'ont_19_film_test_3', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: The director of the movie English Without Tears was an avid actor since 1920. He goes by the name of Harold French. Editing and producing the movie was done by Alan Jaggs and Anatole de Grunwald respectively.\nExample Output: editing(English_Without_Tears,Alan_Jaggs), activeYearsStartYear(Harold_French,1920-01-01), director(English_Without_Tears,Harold_French), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: Cecil Parker had a main role in It's Great to Be Young.\nTest Output: "}
# {'id': 'ont_19_film_test_4', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: \'McVeagh of the South Seas\', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.\nExample Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen), \n\nTest Sentence: The movie "Super Capers" was directed by Ray Griggs.\nTest Output: '}
# {'id': 'ont_19_film_test_5', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: McVeagh of the South Seas was distributed by Alliance Films Corporation.\nExample Output: distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), \n\nTest Sentence: Super Capers was distributed by the public company Lionsgate. It was also distributed by Roadside Attractions.\nTest Output: '}
# {'id': 'ont_19_film_test_6', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.\nExample Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles), \n\nTest Sentence: John Mills had a main role in the movie It\'s Great to Be Young which has taken 282,838 pounds at the box office.\nTest Output: '}
# {'id': 'ont_19_film_test_7', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.\nExample Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0), \n\nTest Sentence: Super Capers, a film written by Ray Griggs, is 98 minutes long. Danielle Harris was one of the stars of the movie.\nTest Output: "}
# {'id': 'ont_19_film_test_8', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: The cinematography of English Without Tears was done by Bernard Knowles.\nExample Output: cinematography(English_Without_Tears,Bernard_Knowles), \n\nTest Sentence: John Mills starred in the 1956 film It’s Great to Be Young which featured cinematography by Gilbert Taylor.\nTest Output: '}
# {'id': 'ont_19_film_test_9', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.\nExample Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), \n\nTest Sentence: The 1956 movie It's Great to Be Young was directed by Cyril Frankel, starred Cecil Parker, and has a running time of 94 minutes.\nTest Output: "}
# {'id': 'ont_19_film_test_10', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.\nExample Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen), \n\nTest Sentence: Director Ray Griggs, born in 1974, is the writer of the film Super Capers, starring Michael Rooker and Tom Sizemore.\nTest Output: "}
# {'id': 'ont_19_film_test_11', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.\nExample Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: John Mills and Cecil Parker starred in the 1956 movie It's Great to Be Young which runs 94 minutes and had Gilbert Taylor as the cinematographer. The movie costed £282,838.\nTest Output: "}
# {'id': 'ont_19_film_test_12', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald. The film was directed by Harold French, an actor whose career began in 1920.\nExample Output: director(English_Without_Tears,Harold_French), deathYear(Terence_Rattigan,1977-01-01), activeYearsStartYear(Harold_French,1920-01-01), writer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Terence_Rattigan), \n\nTest Sentence: Writer of the 1956 film It's Great to Be Young is Ted Willis.\nTest Output: "}
# {'id': 'ont_19_film_test_13', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.\nExample Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), \n\nTest Sentence: Tom Sizemore, who began acting in 1989, and Adam West have both starred in Super Capers.\nTest Output: '}
# {'id': 'ont_19_film_test_14', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: A film named "English Without Tears" was released on July 28th, 1944. The film was edited by Alan Jaggs and produced by Anatole de Grunwald. Interestingly enough, the script was also written by Anatole de Grunwald. Finally, film buffs should know that Bernard Knowles was the cinematographer responsible for the beauty of this movie.\nExample Output: releaseDate(English_Without_Tears,1944-07-28), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), writer(English_Without_Tears,Anatole_de_Grunwald), cinematography(English_Without_Tears,Bernard_Knowles), \n\nTest Sentence: The English-language film Super Capers was edited by Stacy Katzman and played by Michael Rooker.\nTest Output: '}
# {'id': 'ont_19_film_test_15', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.\nExample Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), \n\nTest Sentence: Tom Sizemore stars in Super Capers which starred Michael Rooker.\nTest Output: '}
# {'id': 'ont_19_film_test_16', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: McVeagh of the South Seas, a film with the IMDb #0004319, was distributed by Alliance Films Corporation and produced by the Progressive Motion Picture Company. The film was directed by Cyril Bruce and Harry Carey, who was born in 1878 and also starred in and wrote the film.\nExample Output: imdbId(McVeagh_of_the_South_Seas,0004319), director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), writer(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), producer(McVeagh_of_the_South_Seas,The_Progressive_Motion_Picture_Company), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), \n\nTest Sentence: Super Capers starred Michael Rooker, who was born in Jasper, Alabama.\nTest Output: '}
# {'id': 'ont_19_film_test_17', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89-minute film that was released on July 28th, 1944. It was written by Anatole de Grunwald and directed by Harold French. Nicholas Brodszky was the music composer while Alan Jaggs was the film editor.\nExample Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), writer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: It's great to be young is a movie from 1956 that runs for 94 minutes. It stars Cecil Parker and it’s edited by Max Benedict. Louis Levy composed the music.\nTest Output: "}
# {'id': 'ont_19_film_test_18', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.\nExample Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: John Mills played the lead role and Cecil Parker had a main role in the movie It's Great to Be Young. The movie was released in 1956 and had a duration of 94 minutes. Cyril Frankel is the director and Louis Levy is the music composer of the movie.\nTest Output: "}
# {'id': 'ont_19_film_test_19', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.\nExample Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: Gilbert Taylor was the cinematographer while Cyril Frankel was the director of the movie It's Great to Be Young. It came out in 1956 and lasted 94 minutes and accumulated 282,838 pounds.\nTest Output: "}
# {'id': 'ont_19_film_test_20', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.\nExample Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen), \n\nTest Sentence: “Super Capers” is a 98-minute-long movie starring Tom Lister Jr. Distributed by Lionsgate, the film grossed $30,955. Ray Griggs was the director of the film.\nTest Output: "}
# {'id': 'ont_19_film_test_21', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: The movie English Without Tears' released on July 28, 1994. Produced by Anatole de Grunwald, it also featured Nicholas Brodszky's music compositions while he also worked as part of the non-performing staff.\nExample Output: releaseDate(English_Without_Tears,1944-07-28), producer(English_Without_Tears,Anatole_de_Grunwald), musicComposer(English_Without_Tears,Nicholas_Brodszky), background(Nicholas_Brodszky,non_performing_personnel), \n\nTest Sentence: The film Super Capers, distributed by Lionsgate and starring Justin Whalin, grossed $30,955.\nTest Output: "}
# {'id': 'ont_19_film_test_22', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Anatole de Grunwald was the producer of 'English Without Tears,' a film with a running time of 89 minutes.\nExample Output: producer(English_Without_Tears,Anatole_de_Grunwald), runtime(English_Without_Tears,89.0), \n\nTest Sentence: Super Capers, a film that had a running time of 98 minutes, stars Justin Whalin.\nTest Output: "}
# {'id': 'ont_19_film_test_23', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Harry Carey (born 1878) was a movie actor and starred in and directed McVeagh of the South Seas. Cyril Bruce also directed McVeagh of the South Seas.\nExample Output: director(McVeagh_of_the_South_Seas,Cyril_Bruce), director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), starring(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), \n\nTest Sentence: Super Capers stars the actors Justin Whalin and Michael Rooker. Whalin was born in San Francisco and while the birth location of Rooker is unknown, he was born on April 6th, 1955.\nTest Output: '}
# ...
# {'id': 'ont_19_film_test_120', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: John Mills died in 2005.\nExample Output: deathYear(John_Mills,2005), \n\nTest Sentence: Hayley Mills is the child of John Mills.\nTest Output: '}
# {'id': 'ont_19_film_test_121', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89 minute movie written by Terence Rattigan and released on July 28th, 1944. Alan Jaggs was the editor while Nicholas Brodszky wrote the music for the film.\nExample Output: releaseDate(English_Without_Tears,1944-07-28), writer(English_Without_Tears,Terence_Rattigan), runtime(English_Without_Tears,89.0), editing(English_Without_Tears,Alan_Jaggs), musicComposer(English_Without_Tears,Nicholas_Brodszky), \n\nTest Sentence: The language code (ISO 639-2) of the English language is eng.\nTest Output: '}
# {'id': 'ont_19_film_test_122', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.\nExample Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: Super Capers, an English-language movie, had a running time of 98 minutes and a 2,000,000 dollar budget. Super Capers was edited by Stacy Katzman, written by Ray Griggs, and starred Michael Rooker and Tom Sizemore.\nTest Output: "}
# {'id': 'ont_19_film_test_123', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: The film English Without Tears (89 minutes long) features music composed by Nicholas Brodszky. English Without Tears was edited by Alan Jaggs, and the film's cinematography was done by Bernard Knowles.\nExample Output: musicComposer(English_Without_Tears,Nicholas_Brodszky), editing(English_Without_Tears,Alan_Jaggs), runtime(English_Without_Tears,89.0), cinematography(English_Without_Tears,Bernard_Knowles), \n\nTest Sentence: Featuring Cecil Parker as a main role, It's Great to Be Young was edited by Max Benedict. The composer of music for the film was Louis Levy.\nTest Output: "}
# {'id': 'ont_19_film_test_124', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears, an 89 minute long film released on 1944-07-28, was directed by Harold French. The editing was done by Alan Jaggs, and the composing was done by Nicholas Brodszky.\nExample Output: runtime(English_Without_Tears,89.0), musicComposer(English_Without_Tears,Nicholas_Brodszky), releaseDate(English_Without_Tears,1944-07-28), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), \n\nTest Sentence: It's Great to Be Young (a 1956 film directed by Cyril Frankel) is 94 minutes long. Louis Levy is the music composer for the film, while Cecil Parker had a main role in the film and Ted Willis is the writer.\nTest Output: "}
# {'id': 'ont_19_film_test_125', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: English Without Tears is an 89 minute movie directed by Harold French. The film's editor and producer consisted of two men by the name of Anatole de Grunwald and Alan Jaggs.\nExample Output: runtime(English_Without_Tears,89.0), director(English_Without_Tears,Harold_French), editing(English_Without_Tears,Alan_Jaggs), producer(English_Without_Tears,Anatole_de_Grunwald), \n\nTest Sentence: Super Capers is a film starring Michael Rooker and Tom Sizemore.The film was edited by Stacy Katzman, and the language is English. Roadside Attractions is the distributor of the movie.\nTest Output: "}
# {'id': 'ont_19_film_test_126', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: Adam West got his first role in 1954.\nExample Output: activeYearsStartYear(Adam_West,1954-01-01), \n\nTest Sentence: John Mills is playing the lead in the movie It's Great to Be Young, which was released in 1956.\nTest Output: "}
# {'id': 'ont_19_film_test_127', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations and examples.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: timeshiftChannel(Film,Channel), director(Film,Person), imdbId(Film,), distributor(Film,Company), musicComposer(Film,Artist), type(Film,Type), deathDate(Artist,), club(Film,Club), editing(Film,Artist), releaseDate(Film,), child(Artist,Person), producer(Film,Person), birthPlace(Artist,Place), headquarter(Company,City), deathPlace(Artist,Place), location(Company,Place), budget(Film,), runtime(Film,), owner(Company,Person), starring(Film,Artist), iso6392Code(City,), writer(,Person), industry(Company,Industry), activeYearsStartYear(Artist,), occupation(Artist,Occupation), sisterStation(Film,Station), spouse(Artist,Person), spokenIn(Language,Country), gross(Film,), formerName(Artist,), birthYear(Artist,), birthName(Artist,), editor(Film,Person), language(Film,Language), background(Film,Background), service(Company,Service), cinematography(Film,Cinematography), deathYear(Artist,), birthDate(Artist,), keyPerson(Organisation,Person), foundedBy(Organisation,Person), iso6391Code(Country,), foundingYear(Organisation,), broadcastedBy(Film,Company)\n\nExample Sentence: 'McVeagh of the South Seas', a film distributed by Alliance Films Corporation was directed by Gregory Allen and Harry Carey, an actor born in 1878.\nExample Output: director(McVeagh_of_the_South_Seas,Harry_Carey_(actor_born_1878)), distributor(McVeagh_of_the_South_Seas,Alliance_Films_Corporation), director(McVeagh_of_the_South_Seas,Gregory_Allen), \n\nTest Sentence: Super Capers was distributed by Roadside Attractions and Lionsgate (founded by Frank Giustra).\nTest Output: "}

# %%
output_file_path = os.path.join(output_folder_path, "ont_19_film_baseline_rels_1_shot_prompts.jsonl")
utils.save_jsonl(baseline_one_shot_prompts, output_file_path)
# Out:
# Saved JSONL data to c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\data\dbpedia_new\baseline_rels\ont_19_film_baseline_rels_1_shot_prompts.jsonl
