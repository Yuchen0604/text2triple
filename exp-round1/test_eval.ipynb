# %%
import utils
import argparse
import sys
import os
import json
import re
from typing import List, Dict, Set, Tuple
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
# base directory path
base_dir = r"c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1"
data_dir = os.path.join(base_dir, "data")
wikidata_dir = os.path.join(data_dir, "wikidata_tekgen")
wikidata_new_dir = os.path.join(data_dir, "wikidata_new")
# dbpedia_dir = os.path.join(data_dir, "dbpedia")

ontology_file_path = os.path.join(wikidata_dir, "ontologies", "1_movie_ontology.json")
test_file_path = os.path.join(wikidata_dir, "test/ont_1_movie_test.jsonl")
similarity_file_path = os.path.join(wikidata_dir, "baselines", "test_train_sent_similarity/ont_1_movie_test_train_similarity.json")
train_file_path = os.path.join(wikidata_dir, "train/ont_1_movie_train.jsonl")
ground_truth_file_path = os.path.join(wikidata_dir, "ground_truth/ont_1_movie_ground_truth.jsonl")

file_name = "ont_1_movie_n_rels_0_distractor_0_shot_results.json"
ds_output_path = os.path.join(base_dir, "llm_output", "deepseek-v3", file_name)

# %%
def calculate_precision_recall_f1(gold: set, pred: set) -> Tuple[float, float, float]:
    """
    Method to calculate precision, recall and f1:
        Precision is calculated as correct_triples/predicted_triples and
        Recall as correct_triples/gold_triples
        F1 as the harmonic mean of precision and recall.
    :param gold: items in the gold standard
    :param pred: items in the system prediction
    :return:
        p: float - precision
        r: float - recall
        f1: float - F1

    Example: 
    gold: {
    'newyorklocatedinunitedstates', 
    'berlincapitalofgermany', 
    'pariscapitaloffrance', 
    'machinelearningisaaifield'
    }
    pred: {
    'newyorklocatedinusa', 
    'berlincapitalofgermany', 
    'pariscapitaloffrance', 
    'aiisaatechnology'
    }
    """
    if len(pred) == 0:
        return 0, 0, 0
    p = len(gold.intersection(pred)) / len(pred)
    r = len(gold.intersection(pred)) / len(gold)
    if p + r > 0:
        f1 = 2 * ((p * r) / (p + r))
    else:
        f1 = 0
    return p, r, f1

# %%
def normalize_triple(sub_label: str, rel_label: str, obj_label: str) -> str:
    """
    Normalize triples for comparison in precision, recall calculations
    :param sub_label: subject string
    :param rel_label: relation string
    :param obj_label: object string
    :return: a normalized triple as a single concatenated string

    Example:
    >>> normalize_triple("New York", "located_in", "United States")
    'newyorklocatedinunitedstates'

    >>> normalize_triple("Machine_Learning", "is_a", "AI Field")
    'machinelearningisaaifield'
    """
    # remove spaces and underscores and make lower case
    sub_label = re.sub(r"(_|\s+)", '', sub_label).lower()
    rel_label = re.sub(r"(_|\s+)", '', rel_label).lower()
    obj_label = re.sub(r"(_|\s+)", '', obj_label).lower()
    # concatenate them to a single string
    tr_key = f"{sub_label}{rel_label}{obj_label}"
    return tr_key

# %%
def get_ontology_conformance(ontology: Dict, triples: List) -> Tuple[float, float]:
    """
    Calculate the ontology conformance and relation hallucination metrics.
    :param ontology: ontology to take into account with the concepts and relations
    :param triples: a set of triples generated by the system
    :return:
        ont_conformance: float - ontology conformance metric
        rel_hallucination: float - relation hallucination metric = 1 - ontology conformance
    """
    if len(triples) == 0:
        return 1, 0
    # replace spaces with underscores in the ontology relations
    ont_rels = [rel['label'].replace(" ", "_") for rel in ontology['relations']]
    # count the number of system triples relations that are in the ontology
    num_rels_conformant = len([tr for tr in triples if tr[1] in ont_rels])

    # ontology conformance is the number of system triples relations in the ontology divided by the total number of system triples
    ont_conformance = num_rels_conformant / len(triples)
    # relation hallucination is 1 - ontology conformance
    rel_hallucination = 1 - ont_conformance
    return ont_conformance, rel_hallucination

# %%
# initialize the local variables for the evaluation metrics for each ontology
t_p, t_r, t_f1, t_onto_conf, t_rel_halluc, t_sub_halluc, t_obj_halluc = 0, 0, 0, 0, 0, 0, 0
eval_metrics_list = list()

system_output = utils.load_json(ds_output_path)
ground_truth = utils.load_jsonl(ground_truth_file_path)
ontology = utils.load_json(ontology_file_path)
print(type(system_output), type(ground_truth), type(ontology))
# Out:
# <class 'list'> <class 'list'> <class 'dict'>

# %%
def convert_to_dict(data: List[Dict], id_name: str = "id") -> Dict:
    """
    Utility method to convert a list to a dictionary
    :param data: a list of dictionary objects
    :param id_name: the attribute to be used as the key for the dictionary
    :return: a dictionary with the same content as the list
    """
    return {item[id_name]: item for item in data}

# %%
def clean_entity_string(ps, entity: str) -> str:
    """
    Utility method to clean subject and object strings of triples
    :param ps: stemmer for stemming words before checking for hallucinations
    :param entity: subject or object string
    :return: the cleaned and normalized string
    """
    # stem every word for better matches
    stemmed_entity = "".join([ps.stem(word) for word in word_tokenize(entity)])
    # normalizing the string by removing white spaces, underscores and then converting to lower case
    normalized_stemmed_entity = re.sub(r"(_|\s+)", '', stemmed_entity).lower()
    # special handling for string with years to remove January 01
    return normalized_stemmed_entity.replace("01januari", "")

# %%
def get_subject_object_hallucinations(ps, ontology, test_sentence, triples) -> tuple[float, float]:
    """
    Calculate subject and object hallucinations metrics. As the context for calculating hallucinations, we consider the
    test sentence and the ontology concepts as relevant tokens.
    :param ps: stemmer for stemming words before checking for hallucinations
    :param ontology: ontology to take into account with the concepts and relations
    :param test_sentence: test sentences for which the triples are generated
    :param triples: a set of triples generated by the system
    :return:
        subj_hallucination: float - subject hallucination metric
        obj_hallucination: float - object hallucination metric
    """

    # if the set of triples are empty, we return 0
    if len(triples) == 0:
        return 0, 0

    # append the test sentence with concepts from the ontology
    test_sentence += " ".join([c["label"] for c in ontology['concepts']])
    # stem each word in the test sentence concatenated with the ontology concepts
    stemmed_sentence = "".join([ps.stem(word) for word in word_tokenize(test_sentence)])
    # normalize the text to remove white spaces and underscores
    normalized_stemmed_sentence = re.sub(r"(_|\s+)", '', stemmed_sentence).lower()

    # count the number of subject and object hallucinations
    num_subj_hallucinations, num_obj_hallucinations = 0, 0
    for triple in triples:
        # clean and normalize subject and object noun phrases the same way as the test sentence
        normalized_stemmed_subject = clean_entity_string(ps, triple[0])
        normalized_stemmed_object = clean_entity_string(ps, triple[2])

        # check if the subject/object is found in the stemmed sentence/context text. If not found, mark it as a hallucination
        if normalized_stemmed_sentence.find(normalized_stemmed_subject) == -1:
            num_subj_hallucinations += 1
        if normalized_stemmed_sentence.find(normalized_stemmed_object) == -1:
            num_obj_hallucinations += 1

    # divide the number of hallucinations by the number of triples to calculate the hallucination metrics
    subj_hallucination = num_subj_hallucinations / len(triples)
    obj_hallucination = num_obj_hallucinations / len(triples)
    return subj_hallucination, obj_hallucination

# %%
test = convert_to_dict(system_output)
print(test)
# Out:
# {'ont_1_movie_test_1': {'id': 'ont_1_movie_test_1', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: director(film, human), publication_date(film, ), \n\nTest Sentence: Bleach: Hell Verse (Japanese: BLEACH , Hepburn: BurÄ«chi Jigoku-Hen) is a 2010 Japanese animated film directed by Noriyuki Abe.\nTest Output: ', 'result': 'director(Bleach: Hell Verse, Noriyuki Abe), publication_date(Bleach: Hell Verse, 2010)', 'run_time': 6.019839763641357, 'usage_metadata': 'CompletionUsage(completion_tokens=28, prompt_tokens=132, total_tokens=160, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=128), prompt_cache_hit_tokens=128, prompt_cache_miss_tokens=4)'}, 'ont_1_movie_test_2': {'id': 'ont_1_movie_test_2', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: cast_member(film, human), director(film, human), \n\nTest Sentence: Keyboard Cat's original form was a video originally made in 1984 by Charlie Schmidt of his cat Fatso seemingly playing a piano (though manipulated by Schmidt off-camera) to a cheery tune.\nTest Output: ", 'result': "cast_member(Keyboard Cat's original form, Charlie Schmidt), cast_member(Keyboard Cat's original form, Fatso), director(Keyboard Cat's original form, Charlie Schmidt)", 'run_time': 6.680013656616211, 'usage_metadata': 'CompletionUsage(completion_tokens=37, prompt_tokens=134, total_tokens=171, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=128), prompt_cache_hit_tokens=128, prompt_cache_miss_tokens=6)'}, 'ont_1_movie_test_3': {'id': 'ont_1_movie_test_3', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: director(film, human), \n\nTest Sentence: The series was directed by Mitsuko Kase (episodes 1-7) and Takashi Imanishi (episodes 8-13).\nTest Output: ', 'result': 'director(The series, Mitsuko Kase), director(The series, Takashi Imanishi)', 'run_time': 5.02223539352417, 'usage_metadata': 'CompletionUsage(completion_tokens=20, prompt_tokens=116, total_tokens=136, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=64), prompt_cache_hit_tokens=64, prompt_cache_miss_tokens=52)'}, 'ont_1_movie_test_4': {'id': 'ont_1_movie_test_4', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: genre(film, genre), director(film, human), screenwriter(film, human), production_company(film, film production company), publication_date(film, ), \n\nTest Sentence: Spirited Away (Japanese: , Hepburn: Sen to Chihiro no Kamikakushi, "Sen and Chihiros Spiriting Away") is a 2001 Japanese animated fantasy film written and directed by Hayao Miyazaki, animated by Studio Gh ...

# %%
system_output = convert_to_dict(system_output)
ground_truth = convert_to_dict(ground_truth)
print(system_output)
print(ground_truth)
# Out:
# {'ont_1_movie_test_1': {'id': 'ont_1_movie_test_1', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: director(film, human), publication_date(film, ), \n\nTest Sentence: Bleach: Hell Verse (Japanese: BLEACH , Hepburn: BurÄ«chi Jigoku-Hen) is a 2010 Japanese animated film directed by Noriyuki Abe.\nTest Output: ', 'result': 'director(Bleach: Hell Verse, Noriyuki Abe), publication_date(Bleach: Hell Verse, 2010)', 'run_time': 6.019839763641357, 'usage_metadata': 'CompletionUsage(completion_tokens=28, prompt_tokens=132, total_tokens=160, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=128), prompt_cache_hit_tokens=128, prompt_cache_miss_tokens=4)', 'triples': [['Bleach: Hell Verse', 'director', 'Noriyuki Abe'], ['Bleach: Hell Verse', 'publication_date', '2010']]}, 'ont_1_movie_test_2': {'id': 'ont_1_movie_test_2', 'prompt': "Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: cast_member(film, human), director(film, human), \n\nTest Sentence: Keyboard Cat's original form was a video originally made in 1984 by Charlie Schmidt of his cat Fatso seemingly playing a piano (though manipulated by Schmidt off-camera) to a cheery tune.\nTest Output: ", 'result': "cast_member(Keyboard Cat's original form, Charlie Schmidt), cast_member(Keyboard Cat's original form, Fatso), director(Keyboard Cat's original form, Charlie Schmidt)", 'run_time': 6.680013656616211, 'usage_metadata': 'CompletionUsage(completion_tokens=37, prompt_tokens=134, total_tokens=171, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=128), prompt_cache_hit_tokens=128, prompt_cache_miss_tokens=6)', 'triples': [["Keyboard Cat's original form", 'cast_member', 'Charlie Schmidt'], ["Keyboard Cat's original form", 'cast_member', 'Fatso'], ["Keyboard Cat's original form", 'director', 'Charlie Schmidt']]}, 'ont_1_movie_test_3': {'id': 'ont_1_movie_test_3', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra text, or comments. \n\nCONTEXT:\n\n\nOntology Relations: director(film, human), \n\nTest Sentence: The series was directed by Mitsuko Kase (episodes 1-7) and Takashi Imanishi (episodes 8-13).\nTest Output: ', 'result': 'director(The series, Mitsuko Kase), director(The series, Takashi Imanishi)', 'run_time': 5.02223539352417, 'usage_metadata': 'CompletionUsage(completion_tokens=20, prompt_tokens=116, total_tokens=136, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=64), prompt_cache_hit_tokens=64, prompt_cache_miss_tokens=52)', 'triples': [['The series', 'director', 'Mitsuko Kase'], ['The series', 'director', 'Takashi Imanishi']]}, 'ont_1_movie_test_4': {'id': 'ont_1_movie_test_4', 'prompt': 'Extract relational triplets from the sentence based on the provided ontology relations.\nUse only the listed relations and ensure subjects and objects align with their specified restrictions.\nOnly return the triples in the format relation(subject, object), separated by commas. Do not include explanations, extra t ...
# {'ont_1_movie_test_1': {'id': 'ont_1_movie_test_1', 'sent': 'Bleach: Hell Verse (Japanese: BLEACH , Hepburn: BurÄ«chi Jigoku-Hen) is a 2010 Japanese animated film directed by Noriyuki Abe.', 'triples': [{'sub': 'Bleach : Hell Verse', 'rel': 'director', 'obj': 'Noriyuki Abe'}, {'sub': 'Bleach : Hell Verse', 'rel': 'publication date', 'obj': '01 January 2010'}]}, 'ont_1_movie_test_2': {'id': 'ont_1_movie_test_2', 'sent': "Keyboard Cat's original form was a video originally made in 1984 by Charlie Schmidt of his cat Fatso seemingly playing a piano (though manipulated by Schmidt off-camera) to a cheery tune.", 'triples': [{'sub': 'Keyboard Cat', 'rel': 'cast member', 'obj': 'Fatso the Cat'}, {'sub': 'Keyboard Cat', 'rel': 'director', 'obj': 'Charlie Schmidt'}]}, 'ont_1_movie_test_3': {'id': 'ont_1_movie_test_3', 'sent': 'The series was directed by Mitsuko Kase (episodes 1-7) and Takashi Imanishi (episodes 8-13).', 'triples': [{'sub': 'Mobile Suit Gundam 0083 : Stardust Memory', 'rel': 'director', 'obj': 'Takashi Imanishi'}]}, 'ont_1_movie_test_4': {'id': 'ont_1_movie_test_4', 'sent': 'Spirited Away (Japanese: , Hepburn: Sen to Chihiro no Kamikakushi, "Sen and Chihiros Spiriting Away") is a 2001 Japanese animated fantasy film written and directed by Hayao Miyazaki, animated by Studio Ghibli for Tokuma Shoten, Nippon Television Network, Dentsu, Buena Vista Home Entertainment, Tohokushinsha Film and Mitsubishi, and distributed by Toho.', 'triples': [{'sub': 'Spirited Away', 'rel': 'genre', 'obj': 'Fantasy film'}, {'sub': 'Spirited Away', 'rel': 'director', 'obj': 'Hayao Miyazaki'}, {'sub': 'Spirited Away', 'rel': 'publication date', 'obj': '20 July 2001'}, {'sub': 'Spirited Away', 'rel': 'production company', 'obj': 'Studio Ghibli'}, {'sub': 'Spirited Away', 'rel': 'screenwriter', 'obj': 'Hayao Miyazaki'}]}, 'ont_1_movie_test_5': {'id': 'ont_1_movie_test_5', 'sent': 'Looney Tunes: Back in Action is a 2003 American live-action/animated comedy film directed by Joe Dante and written by Larry Doyle.', 'triples': [{'sub': 'Looney Tunes : Back in Action', 'rel': 'director', 'obj': 'Joe Dante'}, {'sub': 'Looney Tunes : Back in Action', 'rel': 'publication date', 'obj': '01 January 2003'}, {'sub': 'Looney Tunes : Back in Action', 'rel': 'publication date', 'obj': '04 December 2003'}]}, 'ont_1_movie_test_6': {'id': 'ont_1_movie_test_6', 'sent': 'The Life on the Earth - The Summer of Dioxin ( Inochi No Chikyuu - Dioxin No Natsu), also known as Tracing the Gray Summer, is a 2001 Japanese anime drama film by Satoshi Dezaki, a joint production between the Magic Bus and the GoGo Visual Planning which recounts the true story of the Seveso disaster, a chemical incident occurred over the Italian town of Seveso in 1976, which is still considered one of the worst ecological disasters in history.', 'triples': [{'sub': 'Inochi No Chikyuu : Dioxin No Natsu', 'rel': 'director', 'obj': 'Satoshi Dezaki'}, {'sub': 'Inochi No Chikyuu : Dioxin No Natsu', 'rel': 'publication date', 'obj': '00  2001'}, {'sub': 'Inochi No Chikyuu : Dioxin No Natsu', 'rel': 'based on', 'obj': 'Seveso disaster'}]}, 'ont_1_movie_test_7': {'id': 'ont_1_movie_test_7', 'sent': 'Directed by Richard Eichberg and Walter Summers The Flame of Love stars Anna May Wong and John Longden and has a running time of 74 minutes.', 'triples': [{'sub': 'The Flame of Love', 'rel': 'cast member', 'obj': 'Anna May Wong'}, {'sub': 'The Flame of Love', 'rel': 'director', 'obj': 'Richard Eichberg'}]}, 'ont_1_movie_test_8': {'id': 'ont_1_movie_test_8', 'sent': 'Metal Skin Panic MADOX-01 was directed and written by Shinji Aramaki.', 'triples': [{'sub': 'Metal Skin Panic MADOX-01', 'rel': 'director', 'obj': 'Shinji Aramaki'}]}, 'ont_1_movie_test_9': {'id': 'ont_1_movie_test_9', 'sent': 'Directed by Noriyuki Abe, the film was released December 13, 2008 in Japan, later to be released in the US.', 'triples': [{'sub': 'Bleach : Fade to Black', 'rel': 'director', 'obj': 'Noriyuki Abe'}, {'sub': 'Bleach : Fade to Bl ...

# %%
# initialize the local variables for the evaluation metrics for each ontology
t_p, t_r, t_f1, t_onto_conf, t_rel_halluc, t_sub_halluc, t_obj_halluc = 0, 0, 0, 0, 0, 0, 0
eval_metrics_list = list()

eval_output_path = os.path.join(base_dir, "llm_output", "deepseek-v3", "eval_metrics.json")
metric_path = os.path.join(base_dir, "llm_output", "deepseek-v3", "metrics.json")
for sent_id in list(system_output.keys())[0:9]:
    # get system output 
    system_triples = system_output[sent_id]['triples']


    # collect the ground truth triples
    if sent_id in ground_truth:
        gt_triples = [[tr['sub'], tr['rel'], tr['obj']] for tr in ground_truth[sent_id]['triples']]
        sentence = ground_truth[sent_id]["sent"]


        # collect the set of relations in ground truth triples, spaces are converted to "_" to make them
        # comparable with system triples
        gt_relations = {tr[1].replace(" ", "_") for tr in gt_triples}

                
        # filter out any triples in system output that does not match with ground truth relations
        # keep only the triples that have relations in the ground truth
        filtered_system_triples = [tr for tr in system_triples if tr[1] in gt_relations]


        # create a normalized string from subject, relation, object of each triple for comparison
        normalized_system_triples = {normalize_triple(tr[0], tr[1], tr[2]) for tr in filtered_system_triples}
        normalized_gt_triples = {normalize_triple(tr[0], tr[1], tr[2]) for tr in gt_triples}

        # compare the system output triples with ground truth triples and calculate precision, recall, f1
        precision, recall, f1 = calculate_precision_recall_f1(normalized_gt_triples, normalized_system_triples)

        # calculate ontology conformance and relation hallucination
        ont_conformance, rel_hallucination = get_ontology_conformance(ontology, system_triples)


        eval_metrics = {"id": sent_id, "precision": f"{precision:.2f}" , "recall": f"{recall:.2f}", "f1": f"{f1:.2f}",
                                "onto_conf": f"{ont_conformance:.2f}", "rel_halluc": f"{rel_hallucination:.2f}",
                                "llm_triples": system_triples, "filtered_llm_triples": filtered_system_triples,
                                "gt_triples": gt_triples, "sent": sentence}
        eval_metrics_list.append(eval_metrics)
        print(f"eval metrics: {eval_metrics}")

        # aggregate precision, recall, f1 for later averaging
        t_p += precision
        t_r += recall
        t_f1 += f1
        t_onto_conf += ont_conformance
        t_rel_halluc += rel_hallucination


with open(eval_output_path, 'w', encoding='utf-8') as f:
    json.dump(eval_metrics_list, f, ensure_ascii=False, indent=4)

# total_test_cases = len(system_output)
total_test_cases = 9
print(total_test_cases)
# average metrics calculate the average of evaluate metrics for all test cases in a given ontology
average_metrics = {
                           "avg_precision": f"{t_p/total_test_cases:.2f}",
                           "avg_recall": f"{t_r/total_test_cases:.2f}",
                           "avg_f1": f"{t_f1/total_test_cases:.2f}",
                           "avg_onto_conf": f"{t_onto_conf/total_test_cases:.2f}",
                           "avg_rel_halluc": f"{t_rel_halluc / total_test_cases:.2f}",
                           }
with open(metric_path, 'w', encoding='utf-8') as f:
    json.dump(average_metrics, f, ensure_ascii=False, indent=4)
# Out:
# eval metrics: {'id': 'ont_1_movie_test_1', 'precision': '0.50', 'recall': '0.50', 'f1': '0.50', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['Bleach: Hell Verse', 'director', 'Noriyuki Abe'], ['Bleach: Hell Verse', 'publication_date', '2010']], 'filtered_llm_triples': [['Bleach: Hell Verse', 'director', 'Noriyuki Abe'], ['Bleach: Hell Verse', 'publication_date', '2010']], 'gt_triples': [['Bleach : Hell Verse', 'director', 'Noriyuki Abe'], ['Bleach : Hell Verse', 'publication date', '01 January 2010']], 'sent': 'Bleach: Hell Verse (Japanese: BLEACH , Hepburn: BurÄ«chi Jigoku-Hen) is a 2010 Japanese animated film directed by Noriyuki Abe.'}
# eval metrics: {'id': 'ont_1_movie_test_2', 'precision': '0.00', 'recall': '0.00', 'f1': '0.00', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [["Keyboard Cat's original form", 'cast_member', 'Charlie Schmidt'], ["Keyboard Cat's original form", 'cast_member', 'Fatso'], ["Keyboard Cat's original form", 'director', 'Charlie Schmidt']], 'filtered_llm_triples': [["Keyboard Cat's original form", 'cast_member', 'Charlie Schmidt'], ["Keyboard Cat's original form", 'cast_member', 'Fatso'], ["Keyboard Cat's original form", 'director', 'Charlie Schmidt']], 'gt_triples': [['Keyboard Cat', 'cast member', 'Fatso the Cat'], ['Keyboard Cat', 'director', 'Charlie Schmidt']], 'sent': "Keyboard Cat's original form was a video originally made in 1984 by Charlie Schmidt of his cat Fatso seemingly playing a piano (though manipulated by Schmidt off-camera) to a cheery tune."}
# eval metrics: {'id': 'ont_1_movie_test_3', 'precision': '0.00', 'recall': '0.00', 'f1': '0.00', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['The series', 'director', 'Mitsuko Kase'], ['The series', 'director', 'Takashi Imanishi']], 'filtered_llm_triples': [['The series', 'director', 'Mitsuko Kase'], ['The series', 'director', 'Takashi Imanishi']], 'gt_triples': [['Mobile Suit Gundam 0083 : Stardust Memory', 'director', 'Takashi Imanishi']], 'sent': 'The series was directed by Mitsuko Kase (episodes 1-7) and Takashi Imanishi (episodes 8-13).'}
# eval metrics: {'id': 'ont_1_movie_test_4', 'precision': '0.60', 'recall': '0.60', 'f1': '0.60', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['Spirited Away', 'genre', 'fantasy'], ['Spirited Away', 'director', 'Hayao Miyazaki'], ['Spirited Away', 'screenwriter', 'Hayao Miyazaki'], ['Spirited Away', 'production_company', 'Studio Ghibli'], ['Spirited Away', 'publication_date', '2001']], 'filtered_llm_triples': [['Spirited Away', 'genre', 'fantasy'], ['Spirited Away', 'director', 'Hayao Miyazaki'], ['Spirited Away', 'screenwriter', 'Hayao Miyazaki'], ['Spirited Away', 'production_company', 'Studio Ghibli'], ['Spirited Away', 'publication_date', '2001']], 'gt_triples': [['Spirited Away', 'genre', 'Fantasy film'], ['Spirited Away', 'director', 'Hayao Miyazaki'], ['Spirited Away', 'publication date', '20 July 2001'], ['Spirited Away', 'production company', 'Studio Ghibli'], ['Spirited Away', 'screenwriter', 'Hayao Miyazaki']], 'sent': 'Spirited Away (Japanese: , Hepburn: Sen to Chihiro no Kamikakushi, "Sen and Chihiros Spiriting Away") is a 2001 Japanese animated fantasy film written and directed by Hayao Miyazaki, animated by Studio Ghibli for Tokuma Shoten, Nippon Television Network, Dentsu, Buena Vista Home Entertainment, Tohokushinsha Film and Mitsubishi, and distributed by Toho.'}
# eval metrics: {'id': 'ont_1_movie_test_5', 'precision': '0.50', 'recall': '0.33', 'f1': '0.40', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['Looney Tunes: Back in Action', 'director', 'Joe Dante'], ['Looney Tunes: Back in Action', 'publication_date', '2003']], 'filtered_llm_triples': [['Looney Tunes: Back in Action', 'director', 'Joe Dante'], ['Looney Tunes: Back in Action', 'publication_date', '2003']], 'gt_triples': [['Looney Tunes : Back in Action', 'director', 'Joe Dante'], ['Looney Tunes : Back in Action', 'publication date', '01 January 2003'], ['Looney Tunes : Back in Action', 'publication date', '04 December 2003']], 'sent': 'Looney Tunes: Back in Action is a 2003 American live-action/animated comedy film directed by Joe Dante and written by Larry Doyle.'}
# eval metrics: {'id': 'ont_1_movie_test_6', 'precision': '0.00', 'recall': '0.00', 'f1': '0.00', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['The Life on the Earth - The Summer of Dioxin', 'director', 'Satoshi Dezaki'], ['The Life on the Earth - The Summer of Dioxin', 'publication_date', '2001']], 'filtered_llm_triples': [['The Life on the Earth - The Summer of Dioxin', 'director', 'Satoshi Dezaki'], ['The Life on the Earth - The Summer of Dioxin', 'publication_date', '2001']], 'gt_triples': [['Inochi No Chikyuu : Dioxin No Natsu', 'director', 'Satoshi Dezaki'], ['Inochi No Chikyuu : Dioxin No Natsu', 'publication date', '00  2001'], ['Inochi No Chikyuu : Dioxin No Natsu', 'based on', 'Seveso disaster']], 'sent': 'The Life on the Earth - The Summer of Dioxin ( Inochi No Chikyuu - Dioxin No Natsu), also known as Tracing the Gray Summer, is a 2001 Japanese anime drama film by Satoshi Dezaki, a joint production between the Magic Bus and the GoGo Visual Planning which recounts the true story of the Seveso disaster, a chemical incident occurred over the Italian town of Seveso in 1976, which is still considered one of the worst ecological disasters in history.'}
# eval metrics: {'id': 'ont_1_movie_test_7', 'precision': '0.50', 'recall': '1.00', 'f1': '0.67', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['The Flame of Love', 'director', 'Richard Eichberg'], ['The Flame of Love', 'director', 'Walter Summers'], ['The Flame of Love', 'cast_member', 'Anna May Wong'], ['The Flame of Love', 'cast_member', 'John Longden']], 'filtered_llm_triples': [['The Flame of Love', 'director', 'Richard Eichberg'], ['The Flame of Love', 'director', 'Walter Summers'], ['The Flame of Love', 'cast_member', 'Anna May Wong'], ['The Flame of Love', 'cast_member', 'John Longden']], 'gt_triples': [['The Flame of Love', 'cast member', 'Anna May Wong'], ['The Flame of Love', 'director', 'Richard Eichberg']], 'sent': 'Directed by Richard Eichberg and Walter Summers The Flame of Love stars Anna May Wong and John Longden and has a running time of 74 minutes.'}
# eval metrics: {'id': 'ont_1_movie_test_8', 'precision': '1.00', 'recall': '1.00', 'f1': '1.00', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['Metal Skin Panic MADOX-01', 'director', 'Shinji Aramaki']], 'filtered_llm_triples': [['Metal Skin Panic MADOX-01', 'director', 'Shinji Aramaki']], 'gt_triples': [['Metal Skin Panic MADOX-01', 'director', 'Shinji Aramaki']], 'sent': 'Metal Skin Panic MADOX-01 was directed and written by Shinji Aramaki.'}
# eval metrics: {'id': 'ont_1_movie_test_9', 'precision': '0.00', 'recall': '0.00', 'f1': '0.00', 'onto_conf': '1.00', 'rel_halluc': '0.00', 'llm_triples': [['film', 'director', 'Noriyuki Abe'], ['film', 'country_of_origin', 'Japan']], 'filtered_llm_triples': [['film', 'director', 'Noriyuki Abe'], ['film', 'country_of_origin', 'Japan']], 'gt_triples': [['Bleach : Fade to Black', 'director', 'Noriyuki Abe'], ['Bleach : Fade to Black', 'country of origin', 'Japan']], 'sent': 'Directed by Noriyuki Abe, the film was released December 13, 2008 in Japan, later to be released in the US.'}
# 9

# %%
def parse_result(result_str):
    """
    Convert result string from format relation(subject, object) to a list of triples [subject, relation, object].
    If the input does not match the expected format, return an empty list.
    """
    triples = []
    pattern = r'(\w+)\(([^,]+),\s*([^)]+)\)'
    
    matches = re.findall(pattern, result_str)
    
    if not matches:
        return []  # Return empty list if no valid triples are found

    for relation, subject, obj in matches:
        triples.append([subject.strip(), relation.strip(), obj.strip()])
    
    return triples

# %%
ds_folder = os.path.join(base_dir, "llm_output", "deepseek-v3")
gemini_folder = os.path.join(base_dir, "llm_output", "gemini-1.5-flash-8b")

# %%
# directory = ds_folder
directory = gemini_folder
for filename in os.listdir(directory):
    if filename.endswith(".json"):  # Process only JSON files
        file_path = os.path.join(directory, filename)
        print(f"Processing file: {file_path}")
        with open(file_path, "r", encoding="utf-8") as file:
            data = json.load(file)  # Load JSON content
           # Process each JSON object
            for item in data:
                item["triples"] = parse_result(item["result"])
                print(item["triples"])
        # Write back the updated JSON file
        with open(file_path, "w", encoding="utf-8") as file:
            json.dump(data, file, indent=4)
# Out:
# Processing file: c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\llm_output\gemini-1.5-flash-8b\ont_1_movie_n_rels_0_distractor_0_shot_results.json
# [['Bleach: Hell Verse', 'director', 'Noriyuki Abe']]
# []
# [['series', 'director', 'Mitsuko Kase'], ['series', 'director', 'Takashi Imanishi']]
# [['Spirited Away', 'genre', 'animated'], ['Spirited Away', 'director', 'Hayao Miyazaki'], ['Spirited Away', 'screenwriter', 'Hayao Miyazaki'], ['Spirited Away', 'production_company', 'Studio Ghibli']]
# [['Looney Tunes: Back in Action', 'director', 'Joe Dante']]
# [['The Life on the Earth - The Summer of Dioxin ( Inochi No Chikyuu - Dioxin No Natsu)', 'director', 'Satoshi Dezaki']]
# [['The Flame of Love', 'director', 'Richard Eichberg'], ['The Flame of Love', 'director', 'Walter Summers'], ['The Flame of Love', 'cast_member', 'Anna May Wong'], ['The Flame of Love', 'cast_member', 'John Longden']]
# [['Metal Skin Panic MADOX-01', 'director', 'Shinji Aramaki']]
# [['film', 'director', 'Noriyuki Abe'], ['film', 'country_of_origin', 'Japan']]
# [['Fullmetal Alchemist the Movie: Conqueror of Shamballa', 'director', 'Seiji Mizushima']]
# [['Walt Disney', 'director', "Alice's Wonderland"], ["Alice's Wonderland", 'publication_date', '1923'], ["Alice's Wonderland", 'genre', 'short silent film']]
# []
# [['The Night of Taneyamagahara', 'director', 'Kazuo Oga'], ['The Night of Taneyamagahara', 'production_company', 'Studio Ghibli']]
# [['Hiroki Hayashi', 'director', 'The Magnificent World of El-Hazard']]
# [['Daicon IV', 'director', 'Yamaga'], ['Daicon III', 'director', 'Hideaki Anno'], ['Daicon III', 'director', 'Hiroyuki Yamaga'], ['Daicon III', 'director', 'Takami Akai']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo']]
# [['Who Framed Roger Rabbit', 'director', 'Robert Zemeckis']]
# [['Beyond the Clouds', 'director', 'Makoto Shinkai'], ['Beyond the Clouds', 'screenwriter', 'Makoto Shinkai']]
# [['Arcadia of My Youth', 'director', 'Tomoharu Katsumata'], ['Arcadia of My Youth', 'director', 'Kazuo Komatsubara']]
# [['film', 'director', 'Raja Gosnell']]
# [['Toy Story', 'director', 'John Lasseter'], ['Toy Story', 'production_company', 'Pixar']]
# [['Duchamp', 'director', 'AnÃ©mic CinÃ©ma']]
# [['Coal Black and de Sebben Dwarfs', 'director', 'Bob Clampett']]
# [['Mobile Suit Gundam F91', 'director', 'Yoshiyuki Tomino']]
# [['Tom and Jerry', 'director', 'William Hanna'], ['Tom and Jerry', 'director', 'Joseph Barbera']]
# [['Panda ! Go', 'director', 'Panda !, Isao Takahata'], ['Panda ! Go', 'screenwriter', 'Panda !']]
# [["The Wonderful World of Puss 'n Boots", 'director', 'Kimio Yabuki']]
# [['Peter Shin', 'director', 'this episode'], ['Seth MacFarlane', 'screenwriter', 'this episode']]
# [['How a Mosquito Operates', 'director', 'Winsor McCay']]
# [['Bead Game', 'director', 'Ishu Patel']]
# [['Chuck Jones', 'director', 'Cannery Rodent'], ['Cannery Rodent', 'publication_date', '1967']]
# [['Jack and the Witch', 'director', 'Taiji Yabushita']]
# [['Adam Elliot', 'director', 'Harvie Krumpet'], ['Adam Elliot', 'screenwriter', 'Harvie Krumpet'], ['Harvie Krumpet', 'genre', 'comedy-drama']]
# [['Vampire Hunter D: Bloodlust (D  Banpaia HantÄ\x81 DÄ«: Buraddorasuto)', 'director', 'Yoshiaki Kawajiri'], ['Vampire Hunter D: Bloodlust (D  Banpaia HantÄ\x81 DÄ«: Buraddorasuto)', 'screenwriter', 'Yoshiaki Kawajiri']]
# [['Tex Avery', 'director', 'I Love to Singa'], ['I Love to Singa', 'publication_date', '1936']]
# [['Luc Besson', 'director', 'Arthur 3: The War of the Two Worlds'], ['Luc Besson', 'screenwriter', 'Arthur 3: The War of the Two Worlds']]
# [['Hayao Miyazaki', 'director', 'Castle in the Sky'], ['Hayao Miyazaki', 'screenwriter', 'Castle in the Sky']]
# [['The Danish Poet', 'director', 'Torill Kove'], ['The Danish Poet', 'screenwriter', 'Torill Kove']]
# [['Toy Tinkers', 'director', 'Jack Hannah']]
# [["Betty Boop's Bamboo Isle", 'production_company', 'Fleischer Studios'], ["Betty Boop's Bamboo Isle", 'director', 'Dave Fleischer']]
# [['The Secret Life of Pets', 'director', 'Chris Renaud']]
# []
# [['Ghost in the Shell', 'director', 'Mamoru Oshii'], ['film', 'director', 'Mamoru Oshii']]
# [['Dead Leaves', 'director', 'Hiroyuki Imaishi']]
# [['Gertie the Dinosaur', 'cast_member', 'Winsor McCay']]
# [['Flight of the Butterflies', 'director', 'Mike Slee'], ['Flight of the Butterflies', 'cast_member', 'Megan Follows'], ['Flight of the Butterflies', 'cast_member', 'Gordon Pinsent'], ['Flight of the Butterflies', 'cast_member', 'Shaun Benson']]
# [['Les Vampires', 'director', 'Louis Feuillade'], ['Les Vampires', 'screenwriter', 'Louis Feuillade']]
# [['Hayao Miyazaki', 'director', 'The Castle of Cagliostro'], ['Hayao Miyazaki', 'screenwriter', 'The Castle of Cagliostro']]
# [['featurette', 'director', 'Wolfgang Reitherman']]
# [['The Case of the Stuttering Pig', 'director', 'Frank Tashlin']]
# [['Upswept Hare', 'director', 'Robert McKimson']]
# [['My Neighbor Totoro', 'genre', 'animated'], ['My Neighbor Totoro', 'director', 'Hayao Miyazaki'], ['My Neighbor Totoro', 'screenwriter', 'Hayao Miyazaki'], ['My Neighbor Totoro', 'production_company', 'Studio Ghibli']]
# [['Friz Freleng', 'director', 'Yankee Doodle Bugs']]
# [['Tex Avery', 'director', 'Hollywood Steps Out'], ['Hollywood Steps Out', 'publication_date', '1941']]
# [["Mickey's Christmas Carol", 'director', 'Burny Mattinson']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo']]
# [['Walt Disney', 'director', "Alice's Day at Sea"], ["Alice's Day at Sea", 'publication_date', '1924']]
# [['Black Soul', 'director', 'Martine Chartrand']]
# []
# [['Hai-Tang', 'director', 'Richard Eichberg'], ['Hai-Tang', 'director', 'Jean Kemm'], ['Hai-Tang', 'cast_member', 'Anna May Wong'], ['Hai-Tang', 'cast_member', 'Marcel Vibert'], ['Hai-Tang', 'cast_member', 'Robert Ancelin']]
# [['Hiroshi Fujimoto', 'screenwriter', 'plot'], ['Motoo Abiko', 'screenwriter', 'plot']]
# [['Slayers Return', 'director', 'Kunihiko Yuyama'], ['Slayers Return', 'director', 'Hiroshi Watanabe'], ['Slayers Return', 'screenwriter', 'Hajime Kanzaka']]
# [['film', 'director', 'human']]
# [['Who I Am And What I Want', 'director', 'Chris Shepherd'], ['Who I Am And What I Want', 'director', 'David Shrigley']]
# [["Dug's Special Mission (2009)", 'director', 'Ronnie del Carmen']]
# [['When Marnie Was There', 'genre', 'anime'], ['When Marnie Was There', 'director', 'Hiromasa Yonebayashi'], ['When Marnie Was There', 'screenwriter', 'Hiromasa Yonebayashi'], ['When Marnie Was There', 'production_company', 'Studio Ghibli'], ['When Marnie Was There', 'production_company', 'Nippon Television Network'], ['When Marnie Was There', 'production_company', 'Dentsu'], ['When Marnie Was There', 'production_company', 'Hakuhodo DYMP'], ['When Marnie Was There', 'production_company', 'Walt Disney Japan'], ['When Marnie Was There', 'production_company', 'Mitsubishi'], ['When Marnie Was There', 'production_company', 'Toho'], ['When Marnie Was There', 'production_company', 'KDDI'], ['When Marnie Was There', 'country_of_origin', 'Japan']]
# [['screenplay', 'screenwriter', 'Chris Columbus'], ['screenplay', 'screenwriter', 'Richard Outten']]
# [["Mike's New Car", 'director', 'Pete Docter'], ["Mike's New Car", 'director', 'Roger L. Gould']]
# [['Garri Bardin', 'director', 'Seryi Volk & Krasnaya Shapochka']]
# [['Puss Gets the Boot', 'director', 'William Hanna'], ['Puss Gets the Boot', 'director', 'Joseph Barbera'], ['Puss Gets the Boot', 'director', 'Rudolf Ising']]
# [['Superman II', 'director', 'Richard Lester'], ['Superman II', 'screenwriter', 'Mario Puzo'], ['Superman II', 'screenwriter', 'David Newman'], ['Superman II', 'screenwriter', 'Leslie Newman']]
# [['Reiko Yoshida', 'screenwriter', 'Tales of Vesperia : The First Strike']]
# [['Partly Cloudy', 'director', 'Peter Sohn'], ['Partly Cloudy', 'production_company', 'Kevin Reher']]
# [['Satoshi Kon', 'director', 'film']]
# [['Little Nemo in Slumberland', 'screenwriter', 'Winsor McCay']]
# [['Looney Tunes', 'director', 'Bob Clampett'], ['Looney Tunes', 'screenwriter', 'Warren Foster']]
# [['William Hanna', 'director', 'story'], ['Joseph Barbera', 'director', 'story']]
# [['Children Who Chase Stars', 'director', 'Makoto Shinkai']]
# [['She and Her Cat (Japanese:', 'director', 'Hepburn: Kanojo to Kanojo no Neko']]
# [['Brooks', 'screenwriter', 'film'], ['Groening', 'screenwriter', 'film'], ['Jean', 'screenwriter', 'film'], ['Scully', 'screenwriter', 'film'], ['Maxtone-Graham', 'screenwriter', 'film'], ['Meyer', 'screenwriter', 'film'], ['Mirkin', 'screenwriter', 'film'], ['Reiss', 'screenwriter', 'film'], ['Selman', 'screenwriter', 'film'], ['Swartzwelder', 'screenwriter', 'film'], ['Vitti', 'screenwriter', 'film']]
# [['Birds Anonymous', 'director', 'Friz Freleng'], ['Birds Anonymous', 'screenwriter', 'Warren Foster']]
# [['Trap Happy Porky', 'director', 'Chuck Jones'], ['Trap Happy Porky', 'screenwriter', 'Tedd Pierce']]
# [['Mickey Mouse', 'characters', 'cartoon'], ['cartoon', 'publication_date', '1928']]
# [['The Day the Clown Cried', 'director', 'Jerry Lewis'], ['The Day the Clown Cried', 'cast_member', 'Jerry Lewis']]
# [['A Grand Day Out', 'director', 'Nick Park'], ['A Grand Day Out', 'screenwriter', 'Nick Park']]
# [['The twenty-five-and-a-half-minute production', 'director', 'Joss Whedon']]
# [['plot', 'screenwriter', 'Fujiko F. Fujio']]
# [['Brooks', 'screenwriter', 'film'], ['Groening', 'screenwriter', 'film'], ['Jean', 'screenwriter', 'film'], ['Scully', 'screenwriter', 'film'], ['Maxtone-Graham', 'screenwriter', 'film'], ['Meyer', 'screenwriter', 'film'], ['Mirkin', 'screenwriter', 'film'], ['Reiss', 'screenwriter', 'film'], ['Selman', 'screenwriter', 'film'], ['Swartzwelder', 'screenwriter', 'film'], ['Vitti', 'screenwriter', 'film']]
# [["Mike's New Car", 'director', 'Pete Docter'], ["Mike's New Car", 'director', 'Roger L. Gould']]
# [['Japanese rotoscoped youth drama film', 'director', 'Shunji Iwai'], ['Japanese rotoscoped youth drama film', 'screenwriter', 'Shunji Iwai']]
# [['Jones', 'screenwriter', 'plot']]
# []
# [['Catwoman', 'director', 'Lauren Montgomery'], ['Catwoman', 'screenwriter', 'Paul Dini'], ['Catwoman', 'publication_date', '2011']]
# [['Carl Barks', 'screenwriter', 'The short'], ['Chuck Couch', 'screenwriter', 'The short'], ['Jack Hannah', 'screenwriter', 'The short'], ['Harry Reeves', 'screenwriter', 'The short'], ['Milt Schaffer', 'screenwriter', 'The short'], ['Frank Tashlin', 'screenwriter', 'The short']]
# [['Frank Mouris', 'director', 'Frank Film'], ['Frank Film', 'publication_date', '1973']]
# [['Peter Hyams', 'director', 'The Year We Make Contact'], ['The Year We Make Contact', 'genre', 'science fiction'], ['The Year We Make Contact', 'publication_date', '1984']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo']]
# [['Carl Barks', 'screenwriter', 'The short'], ['Chuck Couch', 'screenwriter', 'The short'], ['Jack Hannah', 'screenwriter', 'The short'], ['Harry Reeves', 'screenwriter', 'The short'], ['Milt Schaffer', 'screenwriter', 'The short'], ['Frank Tashlin', 'screenwriter', 'The short']]
# [['Chuck Jones', 'director', 'Tom and Jerry short'], ['Chuck Jones', 'screenwriter', 'Tom and Jerry short']]
# [['short', 'director', 'William Hanna'], ['short', 'director', 'Joseph Barbera']]
# Processing file: c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\llm_output\gemini-1.5-flash-8b\ont_1_movie_n_rels_0_distractor_1_shot_results.json
# [['Bleach: Hell Verse', 'director', 'Noriyuki Abe']]
# []
# [['Tenchi Forever! The Movie', 'director', 'Hiroshi Negishi']]
# [['Spirited Away', 'director', 'Hayao Miyazaki'], ['Spirited Away', 'screenwriter', 'Hayao Miyazaki'], ['Spirited Away', 'production_company', 'Studio Ghibli'], ['Spirited Away', 'production_company', 'Tokuma Shoten'], ['Spirited Away', 'production_company', 'Nippon Television Network'], ['Spirited Away', 'production_company', 'Dentsu'], ['Spirited Away', 'production_company', 'Buena Vista Home Entertainment'], ['Spirited Away', 'production_company', 'Tohokushinsha Film'], ['Spirited Away', 'production_company', 'Mitsubishi'], ['Spirited Away', 'production_company', 'Toho']]
# [['Looney Tunes: Back in Action', 'director', 'Joe Dante']]
# [['The Life on the Earth - The Summer of Dioxin', 'director', 'Satoshi Dezaki']]
# [['The Flame of Love', 'cast_member', 'Anna May Wong'], ['The Flame of Love', 'cast_member', 'John Longden'], ['The Flame of Love', 'director', 'Richard Eichberg'], ['The Flame of Love', 'director', 'Walter Summers']]
# [['Metal Skin Panic MADOX-01', 'director', 'Shinji Aramaki']]
# [['film', 'director', 'Noriyuki Abe']]
# [['Fullmetal Alchemist the Movie: Conqueror of Shamballa', 'director', 'Seiji Mizushima']]
# []
# []
# [['The Night of Taneyamagahara', 'director', 'Kazuo Oga'], ['The Night of Taneyamagahara', 'production_company', 'Studio Ghibli']]
# [['The Magnificent World of El-Hazard', 'director', 'Hiroki Hayashi']]
# [['Daicon IV', 'director', 'Hiroyuki Yamaga'], ['Daicon III', 'director', 'Hideaki Anno'], ['Daicon III', 'director', 'Hiroyuki Yamaga'], ['Daicon III', 'director', 'Takami Akai']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto']]
# [['Who Framed Roger Rabbit', 'director', 'Robert Zemeckis'], ['Who Framed Roger Rabbit', 'screenwriter', 'Jeffrey Price'], ['Who Framed Roger Rabbit', 'screenwriter', 'Peter S. Seaman']]
# [['Beyond the Clouds', 'director', 'Makoto Shinkai']]
# [['Arcadia of My Youth', 'director', 'Tomoharu Katsumata']]
# [['The film', 'director', 'Raja Gosnell']]
# [['Toy Story', 'director', 'John Lasseter'], ['Toy Story', 'production_company', 'Pixar']]
# [['Duchamp', 'director', 'AnÃ©mic CinÃ©ma']]
# [['Coal Black and de Sebben Dwarfs', 'director', 'Bob Clampett']]
# []
# [['Casanova Cat', 'director', 'William Hanna'], ['Casanova Cat', 'director', 'Joseph Barbera']]
# [['Panda ! Go', 'director', 'Panda !,Isao Takahata'], ['Panda ! Go', 'director', 'Panda !,Yoichi Kotabe'], ['Panda ! Go', 'director', 'Panda !,Yasuo Otsuka']]
# [["The Wonderful World of Puss 'n Boots", 'director', 'Kimio Yabuki']]
# [['this episode', 'director', 'Peter Shin'], ['this episode', 'screenwriter', 'Seth MacFarlane']]
# [['How a Mosquito Operates', 'director', 'Winsor McCay']]
# [['Bead Game', 'publication_date', '1977']]
# [['Cannery Rodent', 'director', 'Chuck Jones']]
# [['Jack and the Witch', 'director', 'Taiji Yabushita']]
# [['Harvie Krumpet', 'director', 'Adam Elliot'], ['Harvie Krumpet', 'screenwriter', 'Adam Elliot']]
# [['Vampire Hunter D: Bloodlust', 'director', 'Yoshiaki Kawajiri'], ['Vampire Hunter D: Bloodlust', 'screenwriter', 'Yoshiaki Kawajiri']]
# [['I Love to Singa', 'director', 'Tex Avery']]
# [['Luc Besson', 'director', 'Arthur 3: The War of the Two Worlds'], ['Arthur 3: The War of the Two Worlds', 'based_on', "Arthur 3 : The War of the Two Worlds's novel"]]
# [['Castle in the Sky', 'director', 'Hayao Miyazaki']]
# [['The Danish Poet', 'director', 'Torill Kove'], ['The Danish Poet', 'screenwriter', 'Torill Kove']]
# [['Toy Tinkers', 'director', 'Jack Hannah']]
# [["Betty Boop's Bamboo Isle", 'director', 'Dave Fleischer'], ["Betty Boop's Bamboo Isle", 'production_company', 'Fleischer Studios']]
# [['The Secret Life of Pets', 'director', 'Chris Renaud']]
# [['Chuck Jones', 'director', 'The Dot and the Line'], ['The Dot and the Line', 'publication_date', '1965']]
# [['Ghost in the Shell 2: Innocence', 'director', 'Mamoru Oshii']]
# [['Dead Leaves', 'director', 'Hiroyuki Imaishi']]
# [['Gertie the Dinosaur', 'director', 'Winsor McCay']]
# [['Flight of the Butterflies', 'cast_member', 'Megan Follows'], ['Flight of the Butterflies', 'cast_member', 'Gordon Pinsent'], ['Flight of the Butterflies', 'cast_member', 'Shaun Benson'], ['Flight of the Butterflies', 'director', 'Mike Slee']]
# [['Les Vampires', 'director', 'Louis Feuillade'], ['Les Vampires', 'screenwriter', 'Louis Feuillade']]
# [['The Castle of Cagliostro', 'director', 'Hayao Miyazaki']]
# [['The featurette', 'director', 'Wolfgang Reitherman']]
# [['The Case of the Stuttering Pig', 'director', 'Frank Tashlin']]
# [['Upswept Hare', 'director', 'Robert McKimson']]
# [['My Neighbor Totoro', 'director', 'Hayao Miyazaki']]
# [['Yankee Doodle Bugs', 'director', 'Friz Freleng']]
# [['Hollywood Steps Out', 'director', 'Tex Avery']]
# [["Mickey's Christmas Carol", 'director', 'Burny Mattinson']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto']]
# [["Alice's Day at Sea", 'director', 'Walt Disney']]
# [['Black Soul', 'director', 'Martine Chartrand']]
# []
# [['Hai-Tang', 'cast_member', 'Anna May Wong'], ['Hai-Tang', 'cast_member', 'Marcel Vibert'], ['Hai-Tang', 'cast_member', 'Robert Ancelin'], ['Hai-Tang', 'director', 'Richard Eichberg'], ['Hai-Tang', 'director', 'Jean Kemm']]
# [['The movie', 'screenwriter', 'Hiroshi Fujimoto'], ['The movie', 'screenwriter', 'Motoo Abiko']]
# [['Slayers Return', 'screenwriter', 'Hajime Kanzaka'], ['Slayers Return', 'director', 'Kunihiko Yuyama'], ['Slayers Return', 'director', 'Hiroshi Watanabe']]
# [['The film', 'director', 'Bud Luckey'], ['The film', 'screenwriter', 'Bud Luckey']]
# [['Who I Am And What I Want', 'director', 'Chris Shepherd'], ['Who I Am And What I Want', 'director', 'David Shrigley']]
# [["Dug's Special Mission (2009)", 'director', 'Ronnie del Carmen']]
# [['When Marnie Was There', 'director', 'Hiromasa Yonebayashi'], ['When Marnie Was There', 'screenwriter', 'Hiromasa Yonebayashi'], ['When Marnie Was There', 'production_company', 'Studio Ghibli']]
# [['unknown', 'screenwriter', 'Chris Columbus'], ['unknown', 'screenwriter', 'Richard Outten']]
# [["Mike's New Car", 'director', 'Pete Docter'], ["Mike's New Car", 'director', 'Roger L. Gould']]
# []
# [['Puss Gets the Boot', 'director', 'William Hanna'], ['Puss Gets the Boot', 'director', 'Joseph Barbera'], ['Puss Gets the Boot', 'director', 'Rudolf Ising']]
# [['Superman II', 'director', 'Richard Lester'], ['Superman II', 'screenwriter', 'Mario Puzo'], ['Superman II', 'screenwriter', 'David Newman'], ['Superman II', 'screenwriter', 'Leslie Newman']]
# [['Reiko Yoshida', 'screenwriter', 'Tales of Vesperia : The First Strike']]
# [['Partly Cloudy', 'director', 'Peter Sohn'], ['Partly Cloudy', 'production_company', 'Pixar']]
# [['Satoshi Kon', 'director', 'film']]
# [['Little Nemo in Slumberland', 'screenwriter', 'Winsor McCay']]
# [['Patient Porky', 'director', 'Bob Clampett'], ['Patient Porky', 'screenwriter', 'Warren Foster']]
# [['William Hanna', 'director', 'The story'], ['Joseph Barbera', 'director', 'The story']]
# [['Children Who Chase Stars', 'director', 'Makoto Shinkai']]
# [['She and Her Cat', 'director', 'Makoto Shinkai']]
# [['The Simpsons Movie', 'screenwriter', 'Matt Selman'], ['The Simpsons Movie', 'screenwriter', 'Brooks'], ['The Simpsons Movie', 'screenwriter', 'Groening'], ['The Simpsons Movie', 'screenwriter', 'Jean'], ['The Simpsons Movie', 'screenwriter', 'Scully'], ['The Simpsons Movie', 'screenwriter', 'Maxtone-Graham'], ['The Simpsons Movie', 'screenwriter', 'Meyer'], ['The Simpsons Movie', 'screenwriter', 'Mirkin'], ['The Simpsons Movie', 'screenwriter', 'Reiss'], ['The Simpsons Movie', 'screenwriter', 'Swartzwelder'], ['The Simpsons Movie', 'screenwriter', 'Vitti']]
# [['Birds Anonymous', 'director', 'Friz Freleng'], ['Birds Anonymous', 'screenwriter', 'Warren Foster']]
# [['Trap Happy Porky', 'director', 'Chuck Jones'], ['Trap Happy Porky', 'screenwriter', 'Tedd Pierce']]
# [['Mickey Mouse', 'characters', 'The cartoon']]
# [['The Day the Clown Cried', 'director', 'Jerry Lewis'], ['The Day the Clown Cried', 'cast_member', 'Jerry Lewis']]
# [['A Grand Day Out', 'director', 'Nick Park']]
# [['The twenty-five-and-a-half-minute production', 'director', 'Joss Whedon']]
# [['The original plot', 'screenwriter', 'Fujiko F. Fujio']]
# [['The Simpsons Movie', 'screenwriter', 'Matt Selman'], ['The Simpsons Movie', 'screenwriter', 'Brooks'], ['The Simpsons Movie', 'screenwriter', 'Groening'], ['The Simpsons Movie', 'screenwriter', 'Jean'], ['The Simpsons Movie', 'screenwriter', 'Scully'], ['The Simpsons Movie', 'screenwriter', 'Maxtone-Graham'], ['The Simpsons Movie', 'screenwriter', 'Meyer'], ['The Simpsons Movie', 'screenwriter', 'Mirkin'], ['The Simpsons Movie', 'screenwriter', 'Reiss'], ['The Simpsons Movie', 'screenwriter', 'Swartzwelder'], ['The Simpsons Movie', 'screenwriter', 'Vitti']]
# [["Mike's New Car", 'director', 'Pete Docter'], ["Mike's New Car", 'director', 'Roger L. Gould']]
# [['Hana and Alice murder case', 'director', 'Shunji Iwai'], ['Hana and Alice murder case', 'screenwriter', 'Shunji Iwai']]
# [['Jones', 'screenwriter', 'Michael Maltese']]
# [['The story', 'screenwriter', 'Jack Hannah'], ['The story', 'screenwriter', 'Carl Barks']]
# [['Catwoman', 'director', 'Lauren Montgomery'], ['Catwoman', 'screenwriter', 'Paul Dini']]
# [['The short', 'screenwriter', 'Carl Barks'], ['The short', 'screenwriter', 'Chuck Couch'], ['The short', 'screenwriter', 'Jack Hannah'], ['The short', 'screenwriter', 'Harry Reeves'], ['The short', 'screenwriter', 'Milt Schaffer'], ['The short', 'screenwriter', 'Frank Tashlin']]
# [['Frank Film', 'publication_date', '01 January 1973']]
# [['2010: The Year We Make Contact', 'director', 'Peter Hyams'], ['2010: The Year We Make Contact', 'genre', 'science fiction']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto']]
# [['The short', 'screenwriter', 'Carl Barks'], ['The short', 'screenwriter', 'Chuck Couch'], ['The short', 'screenwriter', 'Jack Hannah'], ['The short', 'screenwriter', 'Harry Reeves'], ['The short', 'screenwriter', 'Milt Schaffer'], ['The short', 'screenwriter', 'Frank Tashlin']]
# [['Jerry', 'director', 'Jerry, Quite Contrary,Chuck Jones'], ['Jerry', 'screenwriter', 'Jerry, Quite Contrary,Chuck Jones']]
# [['The short', 'director', 'William Hanna'], ['The short', 'director', 'Joseph Barbera']]
# Processing file: c:/Users/yuche/OneDrive - TUM/phd/KGC exp/pilot-exp/exp-round1\llm_output\gemini-1.5-flash-8b\ont_1_movie_n_rels_0_distractor_3_shot_results.json
# [['Bleach: Hell Verse', 'director', 'Noriyuki Abe']]
# [["Keyboard Cat's original form", 'director', 'Charlie Schmidt']]
# [['The series', 'director', 'Mitsuko Kase'], ['The series', 'director', 'Takashi Imanishi']]
# [['Spirited Away', 'director', 'Hayao Miyazaki']]
# [['Looney Tunes: Back in Action', 'director', 'Joe Dante']]
# [['The Life on the Earth - The Summer of Dioxin', 'director', 'Satoshi Dezaki']]
# [['The Flame of Love', 'cast_member', 'Anna May Wong'], ['The Flame of Love', 'director', 'Richard Eichberg'], ['The Flame of Love', 'director', 'Walter Summers']]
# [['Metal Skin Panic MADOX-01', 'director', 'Shinji Aramaki']]
# [['Bleach: Memories of Nobody', 'director', 'Noriyuki Abe'], ['Bleach: Memories of Nobody', 'country_of_origin', 'Japan']]
# [['Fullmetal Alchemist the Movie: Conqueror of Shamballa', 'director', 'Seiji Mizushima']]
# [["Alice's Wonderland", 'director', 'Walt Disney']]
# [['Welcome to Eltingville', 'screenwriter', 'Dorkin'], ['Welcome to Eltingville', 'screenwriter', 'Chuck Sheetz']]
# [['The Night of Taneyamagahara', 'director', 'Kazuo Oga'], ['The Night of Taneyamagahara', 'production_company', 'Studio Ghibli']]
# [['The Magnificent World of El-Hazard', 'director', 'Hiroki Hayashi']]
# [['Daicon IV', 'director', 'Hiroyuki Yamaga'], ['Daicon III', 'director', 'Hideaki Anno']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto']]
# [['Who Framed Roger Rabbit', 'director', 'Robert Zemeckis'], ['Who Framed Roger Rabbit', 'screenwriter', 'Jeffrey Price'], ['Who Framed Roger Rabbit', 'screenwriter', 'Peter S. Seaman']]
# [['Beyond the Clouds', 'director', 'the Promised Place,Makoto Shinkai']]
# [['Arcadia of My Youth', 'director', 'Tomoharu Katsumata']]
# [['The film', 'director', 'Raja Gosnell']]
# [['Toy Story', 'director', 'John Lasseter'], ['Toy Story', 'production_company', 'Pixar']]
# [['Duchamp', 'director', 'Man Ray'], ['Duchamp', 'director', 'Marc Allégret']]
# [['Coal Black and de Sebben Dwarfs', 'director', 'Bob Clampett']]
# [['Mobile Suit Gundam F91', 'director', 'Yoshiyuki Tomino']]
# [['Casanova Cat', 'director', 'William Hanna'], ['Casanova Cat', 'director', 'Joseph Barbera'], ['Casanova Cat', 'producer', 'Fred Quimby']]
# [['Panda ! Go', 'director', 'Panda !,Isao Takahata'], ['Panda ! Go', 'screenwriter', 'Panda !,Hayao Miyazaki']]
# [["The Wonderful World of Puss 'n Boots", 'director', 'Kimio Yabuki']]
# [['this episode', 'director', 'Peter Shin'], ['this episode', 'screenwriter', 'Seth MacFarlane'], ['this episode', 'publication_date', '31 January 1999']]
# [['How a Mosquito Operates', 'director', 'Winsor McCay']]
# [['Bead Game', 'director', 'Ishu Patel'], ['Bead Game', 'publication_date', '01 January 1977']]
# [['Cannery Rodent', 'director', 'Chuck Jones']]
# [['Jack and the Witch', 'director', 'Taiji Yabushita']]
# [['Harvie Krumpet', 'director', 'Adam Elliot'], ['Harvie Krumpet', 'screenwriter', 'Adam Elliot']]
# [['Vampire Hunter D: Bloodlust', 'director', 'Yoshiaki Kawajiri'], ['Vampire Hunter D: Bloodlust', 'screenwriter', 'Yoshiaki Kawajiri']]
# [['I Love to Singa', 'director', 'Tex Avery']]
# [['Arthur 3: The War of the Two Worlds', 'director', 'Luc Besson'], ['Arthur 3: The War of the Two Worlds', 'based_on', 'Arthur 3 : The War of the Two Worlds']]
# [['Castle in the Sky', 'director', 'Hayao Miyazaki'], ['Castle in the Sky', 'screenwriter', 'Hayao Miyazaki']]
# [['The Danish Poet', 'director', 'Torill Kove'], ['The Danish Poet', 'screenwriter', 'Torill Kove']]
# [['Toy Tinkers', 'director', 'Jack Hannah']]
# [["Betty Boop's Bamboo Isle", 'director', 'Dave Fleischer'], ["Betty Boop's Bamboo Isle", 'production_company', 'Fleischer Studios']]
# [['The Secret Life of Pets', 'director', 'Chris Renaud'], ['The Secret Life of Pets', 'director', 'Yarrow Cheney'], ['The Secret Life of Pets', 'screenwriter', 'Brian Lynch'], ['The Secret Life of Pets', 'screenwriter', 'Cinco Paul'], ['The Secret Life of Pets', 'screenwriter', 'Ken Daurio']]
# [['The Dot and the Line', 'director', 'Chuck Jones']]
# [['Ghost in the Shell', 'director', 'Mamoru Oshii'], ['Ghost in the Shell 2: Innocence', 'screenwriter', 'Masamune Shirow']]
# [['Dead Leaves', 'director', 'Hiroyuki Imaishi']]
# [['Gertie the Dinosaur', 'director', 'Winsor McCay']]
# [['Flight of the Butterflies', 'cast_member', 'Megan Follows'], ['Flight of the Butterflies', 'cast_member', 'Gordon Pinsent'], ['Flight of the Butterflies', 'cast_member', 'Shaun Benson'], ['Flight of the Butterflies', 'director', 'Mike Slee']]
# [['Les Vampires', 'director', 'Louis Feuillade'], ['Les Vampires', 'screenwriter', 'Louis Feuillade']]
# [['The Castle of Cagliostro', 'director', 'Hayao Miyazaki']]
# [['The featurette', 'director', 'Wolfgang Reitherman']]
# [['The Case of the Stuttering Pig', 'director', 'Frank Tashlin']]
# [['Upswept Hare', 'director', 'Robert McKimson']]
# [['My Neighbor Totoro', 'director', 'Hayao Miyazaki']]
# [['Yankee Doodle Bugs', 'director', 'Friz Freleng']]
# [['Hollywood Steps Out', 'director', 'Tex Avery']]
# [["Mickey's Christmas Carol", 'director', 'Burny Mattinson']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto']]
# [["Alice's Day at Sea", 'director', 'Walt Disney']]
# [['Black Soul', 'director', 'Martine Chartrand']]
# []
# [['Hai-Tang', 'cast_member', 'Anna May Wong'], ['Hai-Tang', 'cast_member', 'Marcel Vibert'], ['Hai-Tang', 'cast_member', 'Robert Ancelin'], ['Hai-Tang', 'director', 'Richard Eichberg'], ['Hai-Tang', 'director', 'Jean Kemm']]
# [["The movie's original plot", 'screenwriter', 'Hiroshi Fujimoto'], ["The movie's original plot", 'screenwriter', 'Motoo Abiko']]
# [['Slayers Return', 'director', 'Kunihiko Yuyama'], ['Slayers Return', 'director', 'Hiroshi Watanabe'], ['Slayers Return', 'screenwriter', 'Hajime Kanzaka']]
# [['The film', 'director', 'Bud Luckey']]
# [['Who I Am And What I Want', 'director', 'Chris Shepherd'], ['Who I Am And What I Want', 'director', 'David Shrigley']]
# [["Dug's Special Mission (2009)", 'director', 'Ronnie del Carmen']]
# [['When Marnie Was There', 'director', 'Hiromasa Yonebayashi']]
# [['?', 'screenwriter', 'Chris Columbus'], ['?', 'screenwriter', 'Richard Outten']]
# [["Mike 's New Car", 'director', 'Pete Docter'], ["Mike 's New Car", 'director', 'Roger L. Gould']]
# []
# [['Puss Gets the Boot', 'director', 'William Hanna'], ['Puss Gets the Boot', 'director', 'Joseph Barbera'], ['Puss Gets the Boot', 'director', 'Rudolf Ising']]
# [['Superman II', 'director', 'Richard Lester'], ['Superman II', 'screenwriter', 'Mario Puzo'], ['Superman II', 'screenwriter', 'David Newman'], ['Superman II', 'screenwriter', 'Leslie Newman']]
# [['Tales of Vesperia : The First Strike', 'director', 'Kanta Kamei'], ['Tales of Vesperia : The First Strike', 'screenwriter', 'Reiko Yoshida']]
# [['Partly Cloudy', 'screenwriter', 'Peter Sohn'], ['Partly Cloudy', 'director', 'Peter Sohn'], ['Partly Cloudy', 'production_company', 'Pixar']]
# [['Millennium Actress', 'director', 'Satoshi Kon']]
# [['Little Nemo in Slumberland', 'screenwriter', 'Winsor McCay']]
# [['Patient Porky', 'director', 'Bob Clampett'], ['Patient Porky', 'screenwriter', 'Warren Foster']]
# [['The story', 'director', 'William Hanna'], ['The story', 'director', 'Joseph Barbera']]
# [['Children Who Chase Stars', 'director', 'Makoto Shinkai']]
# [['She and Her Cat', 'director', 'Makoto Shinkai']]
# [['The Simpsons Movie', 'screenwriter', 'Matt Selman'], ['The Simpsons Movie', 'screenwriter', 'Ian Maxtone-Graham'], ['The Simpsons Movie', 'screenwriter', 'Matt Groening'], ['The Simpsons Movie', 'screenwriter', 'Mike Reiss'], ['The Simpsons Movie', 'screenwriter', 'David Mirkin'], ['The Simpsons Movie', 'screenwriter', 'George Meyer'], ['The Simpsons Movie', 'screenwriter', 'Jon Vitti'], ['The Simpsons Movie', 'screenwriter', 'John Swartzwelder'], ['The Simpsons Movie', 'screenwriter', 'Mike Scully'], ['The Simpsons Movie', 'screenwriter', 'Al Jean'], ['The Simpsons Movie', 'screenwriter', 'Brooks']]
# [['Birds Anonymous', 'director', 'Friz Freleng'], ['Birds Anonymous', 'screenwriter', 'Warren Foster']]
# [['Trap Happy Porky', 'director', 'Chuck Jones'], ['Trap Happy Porky', 'screenwriter', 'Tedd Pierce']]
# [['The cartoon', 'characters', 'Mickey Mouse']]
# [['The Day the Clown Cried', 'director', 'Jerry Lewis'], ['The Day the Clown Cried', 'cast_member', 'Jerry Lewis']]
# [['A Grand Day Out', 'director', 'Nick Park']]
# [['Unaired Buffy the Vampire Slayer pilot', 'director', 'Joss Whedon']]
# [['The original plot', 'screenwriter', 'Fujiko F. Fujio']]
# [['The Simpsons Movie', 'screenwriter', 'Matt Selman'], ['The Simpsons Movie', 'screenwriter', 'Ian Maxtone-Graham'], ['The Simpsons Movie', 'screenwriter', 'Matt Groening'], ['The Simpsons Movie', 'screenwriter', 'Mike Reiss'], ['The Simpsons Movie', 'screenwriter', 'David Mirkin'], ['The Simpsons Movie', 'screenwriter', 'George Meyer'], ['The Simpsons Movie', 'screenwriter', 'Jon Vitti'], ['The Simpsons Movie', 'screenwriter', 'John Swartzwelder'], ['The Simpsons Movie', 'screenwriter', 'Mike Scully'], ['The Simpsons Movie', 'screenwriter', 'Al Jean']]
# [["Mike 's New Car", 'director', 'Pete Docter'], ["Mike 's New Car", 'director', 'Roger L. Gould']]
# [['Hana and Alice murder case', 'director', 'Shunji Iwai'], ['Hana and Alice murder case', 'screenwriter', 'Shunji Iwai']]
# [['Jones', 'screenwriter', 'Michael Maltese']]
# [['The story', 'screenwriter', 'Jack Hannah'], ['The story', 'screenwriter', 'Carl Barks']]
# [['Catwoman', 'director', 'Lauren Montgomery'], ['Catwoman', 'screenwriter', 'Paul Dini']]
# [['The short', 'screenwriter', 'Carl Barks'], ['The short', 'screenwriter', 'Chuck Couch'], ['The short', 'screenwriter', 'Jack Hannah'], ['The short', 'screenwriter', 'Harry Reeves'], ['The short', 'screenwriter', 'Milt Schaffer'], ['The short', 'screenwriter', 'Frank Tashlin']]
# [['Frank Film', 'director', 'Frank Mouris']]
# [['2010: The Year We Make Contact', 'director', 'Peter Hyams']]
# [['The Disappearance of Haruhi Suzumiya', 'production_company', 'Kyoto Animation'], ['The Disappearance of Haruhi Suzumiya', 'screenwriter', 'Fumihiko Shimo'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Tatsuya Ishihara'], ['The Disappearance of Haruhi Suzumiya', 'director', 'Yasuhiro Takemoto']]
# [['The short', 'screenwriter', 'Carl Barks'], ['The short', 'screenwriter', 'Chuck Couch'], ['The short', 'screenwriter', 'Jack Hannah'], ['The short', 'screenwriter', 'Harry Reeves'], ['The short', 'screenwriter', 'Milt Schaffer'], ['The short', 'screenwriter', 'Frank Tashlin']]
# [['Jerry', 'director', 'Jerry, Quite Contrary,Chuck Jones']]
# [['The short', 'director', 'William Hanna'], ['The short', 'director', 'Joseph Barbera']]
